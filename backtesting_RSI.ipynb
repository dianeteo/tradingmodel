# %% [markdown]
# ### Fetching Historical Price Data

# %%
import yfinance as yf
import pandas as pd
import numpy as np

# %%
stocks = {
    'MSFT': '1986-03-13',
    'AAPL': '1980-12-12',
    'NVDA': '1999-01-22',
    'AMZN': '1997-05-15',
    'GOOG': '2004-08-19',
    'META': '2012-05-18',
    'TSLA': '2010-06-29'
}

historical_data = {}

def fetch_historical_data(stocks):
    # Fetching historical data
    for symbol, start_date in stocks.items():
        stock_data = yf.download(symbol, start=start_date, auto_adjust=True)
        historical_data[symbol] = stock_data

    combined_data = pd.concat(historical_data, axis=1)

    return combined_data

combined_data = fetch_historical_data(stocks)

print(combined_data.head())

# combined_data.to_csv("Historical_Data.csv")
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#                            MSFT                            AAPL            \
# Price                     Close High  Low Open Volume     Close      High
# Ticker                     MSFT MSFT MSFT MSFT   MSFT      AAPL      AAPL
# Date
# 1980-12-12 00:00:00+00:00   NaN  NaN  NaN  NaN    NaN  0.098834  0.099264
# 1980-12-15 00:00:00+00:00   NaN  NaN  NaN  NaN    NaN  0.093678  0.094108
# 1980-12-16 00:00:00+00:00   NaN  NaN  NaN  NaN    NaN  0.086802  0.087232
# 1980-12-17 00:00:00+00:00   NaN  NaN  NaN  NaN    NaN  0.088951  0.089381
# 1980-12-18 00:00:00+00:00   NaN  NaN  NaN  NaN    NaN  0.091530  0.091959
#
#                                                           ...  META            \
# Price                           Low      Open     Volume  ... Close High  Low
# Ticker                         AAPL      AAPL       AAPL  ...  META META META
# Date                                                      ...
# 1980-12-12 00:00:00+00:00  0.098834  0.098834  469033600  ...   NaN  NaN  NaN
# 1980-12-15 00:00:00+00:00  0.093678  0.094108  175884800  ...   NaN  NaN  NaN
# 1980-12-16 00:00:00+00:00  0.086802  0.087232  105728000  ...   NaN  NaN  NaN
# 1980-12-17 00:00:00+00:00  0.088951  0.088951   86441600  ...   NaN  NaN  NaN
# 1980-12-18 00:00:00+00:00  0.091530  0.091530   73449600  ...   NaN  NaN  NaN
#
#                                        TSLA
# Price                     Open Volume Close High  Low Open Volume
# Ticker                    META   META  TSLA TSLA TSLA TSLA   TSLA
# Date
# 1980-12-12 00:00:00+00:00  NaN    NaN   NaN  NaN  NaN  NaN    NaN
# 1980-12-15 00:00:00+00:00  NaN    NaN   NaN  NaN  NaN  NaN    NaN
# 1980-12-16 00:00:00+00:00  NaN    NaN   NaN  NaN  NaN  NaN    NaN
# 1980-12-17 00:00:00+00:00  NaN    NaN   NaN  NaN  NaN  NaN    NaN
# 1980-12-18 00:00:00+00:00  NaN    NaN   NaN  NaN  NaN  NaN    NaN
#
# [5 rows x 35 columns]

# %% [markdown]
# ### Calculating Daily RSI

# %%
def calculate_rsi(data, period=14):
    delta = data['Close'].diff()
    gain = delta.where(delta > 0, 0).rolling(window=period).mean()
    loss = -delta.where(delta < 0, 0).rolling(window=period).mean()

    rs = gain / loss
    rsi = 100 - (100 / (1 + rs))
    return rsi

def generate_signals(data, rsi_column='RSI'):
    data['Buy_Signal'] = (data[rsi_column] < 25).shift(1)
    data['Sell_Signal'] = (data[rsi_column] > 75).shift(1)
    return data

signalled_data = {}
OVERBOUGHT = 75
OVERSOLD = 25

# Iterate through each stock in the combined data to calculate RSI and generate buy & sell signals
def calculate_rsi_generate_signals(signalled_data, OVERBOUGHT, OVERSOLD):
    for symbol in combined_data.columns.levels[0]:
        stock_data = combined_data[symbol].dropna()
        
        # Calculate RSI and generate signals
        stock_data['RSI'] = calculate_rsi(stock_data)
        stock_data = generate_signals(stock_data)

        signalled_data[symbol] = stock_data

    combined_data_signalled = pd.concat(signalled_data, axis=1)

    return combined_data_signalled

combined_data_signalled = calculate_rsi_generate_signals(signalled_data, OVERBOUGHT, OVERSOLD)

print(combined_data_signalled)

# combined_data_signalled.to_csv("Historical_Data_Signalled.csv")
# Out:
#                                  MSFT                                      \
# Price                           Close        High         Low        Open
# Ticker                           MSFT        MSFT        MSFT        MSFT
# Date
# 1980-12-12 00:00:00+00:00         NaN         NaN         NaN         NaN
# 1980-12-15 00:00:00+00:00         NaN         NaN         NaN         NaN
# 1980-12-16 00:00:00+00:00         NaN         NaN         NaN         NaN
# 1980-12-17 00:00:00+00:00         NaN         NaN         NaN         NaN
# 1980-12-18 00:00:00+00:00         NaN         NaN         NaN         NaN
# ...                               ...         ...         ...         ...
# 2024-11-04 00:00:00+00:00  408.459991  410.420013  405.570007  409.799988
# 2024-11-05 00:00:00+00:00  411.459991  414.899994  408.079987  408.369995
# 2024-11-06 00:00:00+00:00  420.179993  420.450012  410.519989  412.420013
# 2024-11-07 00:00:00+00:00  425.429993  426.850006  419.880005  421.279999
# 2024-11-08 00:00:00+00:00  422.540009  426.500000  421.779999  425.320007
#
#                                                                          \
# Price                          Volume        RSI Buy_Signal Sell_Signal
# Ticker                           MSFT
# Date
# 1980-12-12 00:00:00+00:00         NaN        NaN        NaN         NaN
# 1980-12-15 00:00:00+00:00         NaN        NaN        NaN         NaN
# 1980-12-16 00:00:00+00:00         NaN        NaN        NaN         NaN
# 1980-12-17 00:00:00+00:00         NaN        NaN        NaN         NaN
# 1980-12-18 00:00:00+00:00         NaN        NaN        NaN         NaN
# ...                               ...        ...        ...         ...
# 2024-11-04 00:00:00+00:00  19672300.0  41.444739      False       False
# 2024-11-05 00:00:00+00:00  17626000.0  46.146209      False       False
# 2024-11-06 00:00:00+00:00  26681800.0  52.522596      False       False
# 2024-11-07 00:00:00+00:00  19901800.0  55.021405      False       False
# 2024-11-08 00:00:00+00:00  16875500.0  52.518089      False       False
#
#                                  AAPL              ...       META              \
# Price                           Close        High  ... Buy_Signal Sell_Signal
# Ticker                           AAPL        AAPL  ...
# Date                                               ...
# 1980-12-12 00:00:00+00:00    0.098834    0.099264  ...        NaN         NaN
# 1980-12-15 00:00:00+00:00    0.093678    0.094108  ...        NaN         NaN
# 1980-12-16 00:00:00+00:00    0.086802    0.087232  ...        NaN         NaN
# 1980-12-17 00:00:00+00:00    0.088951    0.089381  ...        NaN         NaN
# 1980-12-18 00:00:00+00:00    0.091530    0.091959  ...        NaN         NaN
# ...                               ...         ...  ...        ...         ...
# 2024-11-04 00:00:00+00:00  221.766006  222.545148  ...      False       False
# 2024-11-05 00:00:00+00:00  223.204422  223.703872  ...      False       False
# 2024-11-06 00:00:00+00:00  222.475235  225.821559  ...      False       False
# 2024-11-07 00:00:00+00:00  227.229996  227.629565  ...      False       False
# 2024-11-08 00:00:00+00:00  226.960007  228.660004  ...      False       False
#
#                                  TSLA                                      \
# Price                           Close        High         Low        Open
# Ticker                           TSLA        TSLA        TSLA        TSLA
# Date
# 1980-12-12 00:00:00+00:00         NaN         NaN         NaN         NaN
# 1980-12-15 00:00:00+00:00         NaN         NaN         NaN         NaN
# 1980-12-16 00:00:00+00:00         NaN         NaN         NaN         NaN
# 1980-12-17 00:00:00+00:00         NaN         NaN         NaN         NaN
# 1980-12-18 00:00:00+00:00         NaN         NaN         NaN         NaN
# ...                               ...         ...         ...         ...
# 2024-11-04 00:00:00+00:00  242.839996  248.899994  238.880005  244.559998
# 2024-11-05 00:00:00+00:00  251.440002  255.279999  246.210007  247.339996
# 2024-11-06 00:00:00+00:00  288.529999  289.589996  275.619995  284.670013
# 2024-11-07 00:00:00+00:00  296.910004  299.750000  285.519989  288.890015
# 2024-11-08 00:00:00+00:00  321.220001  328.709991  297.660004  299.140015
#
#
# Price                           Volume        RSI Buy_Signal Sell_Signal
# Ticker                            TSLA
# Date
# 1980-12-12 00:00:00+00:00          NaN        NaN        NaN         NaN
# 1980-12-15 00:00:00+00:00          NaN        NaN        NaN         NaN
# 1980-12-16 00:00:00+00:00          NaN        NaN        NaN         NaN
# 1980-12-17 00:00:00+00:00          NaN        NaN        NaN         NaN
# 1980-12-18 00:00:00+00:00          NaN        NaN        NaN         NaN
# ...                                ...        ...        ...         ...
# 2024-11-04 00:00:00+00:00   68802400.0  62.739508      False       False
# 2024-11-05 00:00:00+00:00   69282500.0  65.335638      False       False
# 2024-11-06 00:00:00+00:00  165228700.0  75.085294      False       False
# 2024-11-07 00:00:00+00:00  117309200.0  76.644988      False        True
# 2024-11-08 00:00:00+00:00  203590100.0  80.933092      False        True
#
# [11070 rows x 56 columns]

# %% [markdown]
# ### Backtesting using Relative Strength Index

# %%
symbol_list = ['MSFT', 'AAPL', 'NVDA', 'AMZN', 'GOOG', 'META', 'TSLA']

# Requirements
INITIAL_CAPITAL = 1_000_000
COMMISSION_RATE = 0.001
SLIPPAGE_RATE = 0.0002
MIN_SHARES = 10
MAX_ALLOCATION = 0.3
RISK_FREE_RATE = 0.02
TRADING_DAYS_PER_YEAR = 252
BACKTEST_START_DATE = '1981-01-01'
BACKTEST_END_DATE = '2023-12-31'

def backtesting_strategy(INITIAL_CAPITAL, COMMISSION_RATE, SLIPPAGE_RATE, MIN_SHARES, MAX_ALLOCATION, BACKTEST_START_DATE, BACKTEST_END_DATE):
    portfolio_value = INITIAL_CAPITAL
    cash = INITIAL_CAPITAL
    portfolio = {}
    portfolio_history = []
    trade_count = 0
    trade_returns = []
    wins = 0
    # Backtesting loop by date
    for date in combined_data_signalled.index[(combined_data_signalled.index >= BACKTEST_START_DATE) & (combined_data_signalled.index <= BACKTEST_END_DATE)]:
        print(f"Current date: {date}")
        buy_stocks = []
        sell_stocks = []

        for symbol in symbol_list:
            if (symbol, 'Buy_Signal') in combined_data_signalled.columns and combined_data_signalled.loc[date, (symbol, 'Buy_Signal')] == True:
                buy_stocks.append(symbol)
            if (symbol, 'Sell_Signal') in combined_data_signalled.columns and combined_data_signalled.loc[date, (symbol, 'Sell_Signal')] == True:
                sell_stocks.append(symbol)

        # print(date, buy_stocks)
        # print(date, sell_stocks)

        # Sell trades
        for stock in sell_stocks:
            print('TIME TO SELL')
            if stock in portfolio:
                sell_price = combined_data_signalled.loc[date, (stock, 'Close')][stock] * (1 - COMMISSION_RATE - SLIPPAGE_RATE)
                print(f"Sell price of {stock}:", sell_price)
                num_shares = portfolio[stock]
                proceeds = sell_price * num_shares
                cash += float(proceeds)
                trade_return = (sell_price * num_shares - INITIAL_CAPITAL / len(portfolio)) / (INITIAL_CAPITAL / len(portfolio))
                trade_returns.append(trade_return)
                wins += trade_return > 0
                del portfolio[stock]
                print(f"Sold {stock} for", proceeds)
                trade_count += 1
            else:
                print(f"{stock} not in portfolio")

        # Buy trades
        for stock in buy_stocks:
            print('TIME TO BUY')
            stock_close_price = combined_data_signalled.loc[date, (stock, 'Close')][stock]
            print(f"Buy price of {stock}:", stock_close_price)
            allocation_per_stock = min(float(cash) / len(buy_stocks), float(portfolio_value) * MAX_ALLOCATION)

            print("Cash on hand:", cash)

            if (stock not in portfolio) and (allocation_per_stock > MIN_SHARES * stock_close_price):
                buy_price = stock_close_price * (1 + COMMISSION_RATE + SLIPPAGE_RATE)
                num_shares = int(allocation_per_stock / buy_price)
                cost = buy_price * num_shares

                if cost <= cash: 
                    portfolio[stock] = num_shares
                    cash -= cost
                    print(f"Bought {stock} for", cost)
                    trade_count += 1

        # Rebalancing portfolio
        total_aum = cash + sum(combined_data_signalled.loc[date, (stock, 'Close')][stock] * shares for stock, shares in portfolio.items())
        for stock in portfolio:
            stock_value = combined_data_signalled.loc[date, (stock, 'Close')][stock] * portfolio[stock]
            if stock_value / total_aum > MAX_ALLOCATION:
                print(f"{stock} has excess shares, reallocating portfolio")
                excess_shares = portfolio[stock] - int(MAX_ALLOCATION * total_aum / combined_data_signalled.loc[date, (stock, 'Close')][stock])
                sell_price = combined_data_signalled.loc[date, (stock, 'Close')][stock] * (1 - COMMISSION_RATE - SLIPPAGE_RATE)
                cash += sell_price * excess_shares
                portfolio[stock] -= excess_shares
                print(f"{excess_shares} of {stock} sold for {sell_price} to rebalance portfolio")

        # Calculate daily portfolio value
        portfolio_value = cash + sum(combined_data_signalled.loc[date, (stock, 'Close')][stock] * shares for stock, shares in portfolio.items())
        portfolio_history.append(portfolio_value)
        print(f"Current portfolio value: {portfolio_value}")

    return portfolio_history, portfolio_value, trade_returns, trade_count, wins

portfolio_history, portfolio_value, trade_returns, trade_count, wins = backtesting_strategy(INITIAL_CAPITAL, COMMISSION_RATE, SLIPPAGE_RATE, MIN_SHARES, MAX_ALLOCATION, BACKTEST_START_DATE, BACKTEST_END_DATE)
# Out:
# Current date: 1981-01-02 00:00:00+00:00
# Current portfolio value: 1000000
# Current date: 1981-01-05 00:00:00+00:00
# Current portfolio value: 1000000
# Current date: 1981-01-06 00:00:00+00:00
# Current portfolio value: 1000000
# Current date: 1981-01-07 00:00:00+00:00
# Current portfolio value: 1000000
# Current date: 1981-01-08 00:00:00+00:00
# Current portfolio value: 1000000
# Current date: 1981-01-09 00:00:00+00:00
# Current portfolio value: 1000000
# Current date: 1981-01-12 00:00:00+00:00
# Current portfolio value: 1000000
# Current date: 1981-01-13 00:00:00+00:00
# Current portfolio value: 1000000
# Current date: 1981-01-14 00:00:00+00:00
# Current portfolio value: 1000000
# Current date: 1981-01-15 00:00:00+00:00
# Current portfolio value: 1000000
# Current date: 1981-01-16 00:00:00+00:00
# Current portfolio value: 1000000
# Current date: 1981-01-19 00:00:00+00:00
# Current portfolio value: 1000000
# Current date: 1981-01-20 00:00:00+00:00
# Current portfolio value: 1000000
# Current date: 1981-01-21 00:00:00+00:00
# Current portfolio value: 1000000
# Current date: 1981-01-22 00:00:00+00:00
# Current portfolio value: 1000000
# Current date: 1981-01-23 00:00:00+00:00
# Current portfolio value: 1000000
# Current date: 1981-01-26 00:00:00+00:00
# Current portfolio value: 1000000
# Current date: 1981-01-27 00:00:00+00:00
# Current portfolio value: 1000000
# Current date: 1981-01-28 00:00:00+00:00
# Current portfolio value: 1000000
# Current date: 1981-01-29 00:00:00+00:00
# Current portfolio value: 1000000
# Current date: 1981-01-30 00:00:00+00:00
# Current portfolio value: 1000000
# Current date: 1981-02-02 00:00:00+00:00
# Current portfolio value: 1000000
# Current date: 1981-02-03 00:00:00+00:00
# Current portfolio value: 1000000
# Current date: 1981-02-04 00:00:00+00:00
# Current portfolio value: 1000000
# Current date: 1981-02-05 00:00:00+00:00
# Current portfolio value: 1000000
# Current date: 1981-02-06 00:00:00+00:00
# Current portfolio value: 1000000
# Current date: 1981-02-09 00:00:00+00:00
# Current portfolio value: 1000000
# Current date: 1981-02-10 00:00:00+00:00
# Current portfolio value: 1000000
# Current date: 1981-02-11 00:00:00+00:00
# TIME TO BUY
# Buy price of AAPL: 0.09067044407129288
# Cash on hand: 1000000
# Bought AAPL for 299999.9984472005
# Current portfolio value: 999640.4314840825
# Current date: 1981-02-12 00:00:00+00:00
# TIME TO BUY
# Buy price of AAPL: 0.08981025964021683
# Cash on hand: 700000.0015527995
# Current portfolio value: 996797.7627910168
# Current date: 1981-02-13 00:00:00+00:00
# TIME TO BUY
# Buy price of AAPL: 0.08766182512044907
# Cash on hand: 700000.0015527995
# Current portfolio value: 989697.7882648499
# Current date: 1981-02-17 00:00:00+00:00
# TIME TO BUY
# Buy price of AAPL: 0.08981025964021683
# Cash on hand: 700000.0015527995
# Current portfolio value: 996797.7627910168
# Current date: 1981-02-18 00:00:00+00:00
# TIME TO BUY
# Buy price of AAPL: 0.09367822110652924
# Cash on hand: 700000.0015527995
# AAPL has excess shares, reallocating portfolio
# 71588 of AAPL sold for 0.0935658072412014 to rebalance portfolio
# Current portfolio value: 1009572.2449241776
# Current date: 1981-02-19 00:00:00+00:00
# Current portfolio value: 991509.5421192844
# Current date: 1981-02-20 00:00:00+00:00
# Current portfolio value: 976227.977301826
# Current date: 1981-02-23 00:00:00+00:00
# Current portfolio value: 980395.6373796065
# Current date: 1981-02-24 00:00:00+00:00
# Current portfolio value: 970671.0971981187
# Current date: 1981-02-25 00:00:00+00:00
# Current portfolio value: 987341.9543076355
# Current date: 1981-02-26 00:00:00+00:00
# Current portfolio value: 991509.5421192844
# Current date: 1981-02-27 00:00:00+00:00
# Current portfolio value: 1001236.9247686167
# Current date: 1981-03-02 00:00:00+00:00
# Current portfolio value: 1002626.0725284119
# Current date: 1981-03-03 00:00:00+00:00
# Current portfolio value: 998458.1956522365
# Current date: 1981-03-04 00:00:00+00:00
# Current portfolio value: 995677.2021970649
# Current date: 1981-03-05 00:00:00+00:00
# Current portfolio value: 994288.1267034013
# Current date: 1981-03-06 00:00:00+00:00
# Current portfolio value: 991509.5421192844
# Current date: 1981-03-09 00:00:00+00:00
# Current portfolio value: 969281.7326399286
# Current date: 1981-03-10 00:00:00+00:00
# Current portfolio value: 956776.2471806903
# Current date: 1981-03-11 00:00:00+00:00
# Current portfolio value: 947051.4420233865
# Current date: 1981-03-12 00:00:00+00:00
# Current portfolio value: 956776.2471806903
# Current date: 1981-03-13 00:00:00+00:00
# Current portfolio value: 953997.7830401261
# Current date: 1981-03-16 00:00:00+00:00
# Current portfolio value: 963724.7802700896
# Current date: 1981-03-17 00:00:00+00:00
# Current portfolio value: 976227.977301826
# Current date: 1981-03-18 00:00:00+00:00
# Current portfolio value: 992898.930766185
# Current date: 1981-03-19 00:00:00+00:00
# Current portfolio value: 990120.4425369103
# Current date: 1981-03-20 00:00:00+00:00
# Current portfolio value: 992898.930766185
# Current date: 1981-03-23 00:00:00+00:00
# Current portfolio value: 1004015.3166430492
# Current date: 1981-03-24 00:00:00+00:00
# Current portfolio value: 1002626.0725284119
# Current date: 1981-03-25 00:00:00+00:00
# Current portfolio value: 997066.6149326761
# Current date: 1981-03-26 00:00:00+00:00
# Current portfolio value: 991509.5421192844
# Current date: 1981-03-27 00:00:00+00:00
# Current portfolio value: 981784.8814942439
# Current date: 1981-03-30 00:00:00+00:00
# Current portfolio value: 981784.8814942439
# Current date: 1981-03-31 00:00:00+00:00
# Current portfolio value: 979006.5137085218
# Current date: 1981-04-01 00:00:00+00:00
# Current portfolio value: 976227.977301826
# Current date: 1981-04-02 00:00:00+00:00
# Current portfolio value: 999847.7047426898
# Current date: 1981-04-03 00:00:00+00:00
# Current portfolio value: 1001236.9247686167
# Current date: 1981-04-06 00:00:00+00:00
# Current portfolio value: 995677.2021970649
# Current date: 1981-04-07 00:00:00+00:00
# Current portfolio value: 992898.930766185
# Current date: 1981-04-08 00:00:00+00:00
# Current portfolio value: 1006793.8530497451
# Current date: 1981-04-09 00:00:00+00:00
# AAPL has excess shares, reallocating portfolio
# 20599 of AAPL sold for 0.09442416319549084 to rebalance portfolio
# Current portfolio value: 1012348.4203859302
# Current date: 1981-04-10 00:00:00+00:00
# AAPL has excess shares, reallocating portfolio
# 30258 of AAPL sold for 0.09571167852282525 to rebalance portfolio
# Current portfolio value: 1016486.0958207571
# Current date: 1981-04-13 00:00:00+00:00
# AAPL has excess shares, reallocating portfolio
# 11 of AAPL sold for 0.09571167852282525 to rebalance portfolio
# Current portfolio value: 1016486.094555845
# Current date: 1981-04-14 00:00:00+00:00
# Current portfolio value: 1016486.094555845
# Current date: 1981-04-15 00:00:00+00:00
# Current portfolio value: 1001444.9836684368
# Current date: 1981-04-16 00:00:00+00:00
# Current portfolio value: 985033.8069336913
# Current date: 1981-04-20 00:00:00+00:00
# Current portfolio value: 993238.1742507718
# Current date: 1981-04-21 00:00:00+00:00
# Current portfolio value: 1012383.9583167336
# Current date: 1981-04-22 00:00:00+00:00
# AAPL has excess shares, reallocating portfolio
# 48847 of AAPL sold for 0.09785752747952939 to rebalance portfolio
# Current portfolio value: 1023317.213727234
# Current date: 1981-04-23 00:00:00+00:00
# AAPL has excess shares, reallocating portfolio
# 56255 of AAPL sold for 0.10043257301747799 to rebalance portfolio
# Current portfolio value: 1031388.8113074385
# Current date: 1981-04-24 00:00:00+00:00
# Current portfolio value: 1028744.2688340627
# Current date: 1981-04-27 00:00:00+00:00
# Current portfolio value: 1026099.8639205479
# Current date: 1981-04-28 00:00:00+00:00
# Current portfolio value: 1020811.0770201617
# Current date: 1981-04-29 00:00:00+00:00
# Current portfolio value: 1016844.4008699589
# Current date: 1981-04-30 00:00:00+00:00
# Current portfolio value: 1022133.2794769191
# Current date: 1981-05-01 00:00:00+00:00
# Current portfolio value: 1022133.2794769191
# Current date: 1981-05-04 00:00:00+00:00
# Current portfolio value: 1020811.0770201617
# Current date: 1981-05-05 00:00:00+00:00
# Current portfolio value: 1019488.8974900477
# Current date: 1981-05-06 00:00:00+00:00
# Current portfolio value: 1011555.5451896422
# Current date: 1981-05-07 00:00:00+00:00
# Current portfolio value: 1015522.0608533405
# Current date: 1981-05-08 00:00:00+00:00
# Current portfolio value: 1018166.6033267163
# Current date: 1981-05-11 00:00:00+00:00
# Current portfolio value: 1011555.5451896422
# Current date: 1981-05-12 00:00:00+00:00
# Current portfolio value: 1011555.5451896422
# Current date: 1981-05-13 00:00:00+00:00
# Current portfolio value: 1010233.2739529543
# Current date: 1981-05-14 00:00:00+00:00
# Current portfolio value: 1006266.5748761081
# Current date: 1981-05-15 00:00:00+00:00
# Current portfolio value: 1012877.7476463997
# Current date: 1981-05-18 00:00:00+00:00
# Current portfolio value: 1018166.6033267163
# Current date: 1981-05-19 00:00:00+00:00
# Current portfolio value: 1012877.7476463997
# Current date: 1981-05-20 00:00:00+00:00
# Current portfolio value: 1022133.2794769191
# Current date: 1981-05-21 00:00:00+00:00
# AAPL has excess shares, reallocating portfolio
# 53881 of AAPL sold for 0.10300834039449693 to rebalance portfolio
# Current portfolio value: 1039317.7192595168
# Current date: 1981-05-22 00:00:00+00:00
# AAPL has excess shares, reallocating portfolio
# 92760 of AAPL sold for 0.10772927953898907 to rebalance portfolio
# Current portfolio value: 1053595.5867566487
# Current date: 1981-05-26 00:00:00+00:00
# Current portfolio value: 1052336.284191223
# Current date: 1981-05-27 00:00:00+00:00
# AAPL has excess shares, reallocating portfolio
# 101039 of AAPL sold for 0.11330849277973175 to rebalance portfolio
# Current portfolio value: 1069951.477098371
# Current date: 1981-05-28 00:00:00+00:00
# TIME TO SELL
# Sell price of AAPL: 0.11330849277973175
# Sold AAPL for 320604.34076738096
# Current portfolio value: 1069566.2896645295
# Current date: 1981-05-29 00:00:00+00:00
# TIME TO SELL
# AAPL not in portfolio
# Current portfolio value: 1069566.2896645295
# Current date: 1981-06-01 00:00:00+00:00
# TIME TO SELL
# AAPL not in portfolio
# Current portfolio value: 1069566.2896645295
# Current date: 1981-06-02 00:00:00+00:00
# TIME TO SELL
# AAPL not in portfolio
# Current portfolio value: 1069566.2896645295
# Current date: 1981-06-03 00:00:00+00:00
# Current portfolio value: 1069566.2896645295
# Current date: 1981-06-04 00:00:00+00:00
# Current portfolio value: 1069566.2896645295
# Current date: 1981-06-05 00:00:00+00:00
# TIME TO SELL
# AAPL not in portfolio
# Current portfolio value: 1069566.2896645295
# Current date: 1981-06-08 00:00:00+00:00
# Current portfolio value: 1069566.2896645295
# Current date: 1981-06-09 00:00:00+00:00
# Current portfolio value: 1069566.2896645295
# Current date: 1981-06-10 00:00:00+00:00
# Current portfolio value: 1069566.2896645295
# Current date: 1981-06-11 00:00:00+00:00
# Current portfolio value: 1069566.2896645295
# Current date: 1981-06-12 00:00:00+00:00
# Current portfolio value: 1069566.2896645295
# Current date: 1981-06-15 00:00:00+00:00
# Current portfolio value: 1069566.2896645295
# Current date: 1981-06-16 00:00:00+00:00
# Current portfolio value: 1069566.2896645295
# Current date: 1981-06-17 00:00:00+00:00
# Current portfolio value: 1069566.2896645295
# Current date: 1981-06-18 00:00:00+00:00
# Current portfolio value: 1069566.2896645295
# Current date: 1981-06-19 00:00:00+00:00
# Current portfolio value: 1069566.2896645295
# Current date: 1981-06-22 00:00:00+00:00
# Current portfolio value: 1069566.2896645295
# Current date: 1981-06-23 00:00:00+00:00
# Current portfolio value: 1069566.2896645295
# Current date: 1981-06-24 00:00:00+00:00
# Current portfolio value: 1069566.2896645295
# Current date: 1981-06-25 00:00:00+00:00
# Current portfolio value: 1069566.2896645295
# Current date: 1981-06-26 00:00:00+00:00
# Current portfolio value: 1069566.2896645295
# Current date: 1981-06-29 00:00:00+00:00
# Current portfolio value: 1069566.2896645295
# Current date: 1981-06-30 00:00:00+00:00
# Current portfolio value: 1069566.2896645295
# Current date: 1981-07-01 00:00:00+00:00
# TIME TO BUY
# Buy price of AAPL: 0.08852120488882065
# Cash on hand: 1069566.2896645295
# Bought AAPL for 320869.8507437633
# Current portfolio value: 1069181.7073424235
# Current date: 1981-07-02 00:00:00+00:00
# TIME TO BUY
# Buy price of AAPL: 0.08852120488882065
# Cash on hand: 748696.4389207661
# Current portfolio value: 1069181.7073424235
# Current date: 1981-07-06 00:00:00+00:00
# TIME TO BUY
# Buy price of AAPL: 0.08551333844661713
# Cash on hand: 748696.4389207661
# Current portfolio value: 1058291.9223997444
# Current date: 1981-07-07 00:00:00+00:00
# TIME TO BUY
# Buy price of AAPL: 0.0863727331161499
# Cash on hand: 748696.4389207661
# Current portfolio value: 1061403.3049401343
# Current date: 1981-07-08 00:00:00+00:00
# TIME TO BUY
# Buy price of AAPL: 0.08981025964021683
# Cash on hand: 748696.4389207661
# AAPL has excess shares, reallocating portfolio
# 33378 of AAPL sold for 0.08970248732864856 to rebalance portfolio
# Current portfolio value: 1073845.049057079
# Current date: 1981-07-09 00:00:00+00:00
# TIME TO BUY
# Buy price of AAPL: 0.08293525874614716
# Cash on hand: 751690.5285428218
# Current portfolio value: 1049184.0289750001
# Current date: 1981-07-10 00:00:00+00:00
# TIME TO BUY
# Buy price of AAPL: 0.0764891728758812
# Cash on hand: 751690.5285428218
# Current portfolio value: 1026061.5515314615
# Current date: 1981-07-13 00:00:00+00:00
# TIME TO BUY
# Buy price of AAPL: 0.07820869237184525
# Cash on hand: 751690.5285428218
# Current portfolio value: 1032229.5659760959
# Current date: 1981-07-14 00:00:00+00:00
# TIME TO BUY
# Buy price of AAPL: 0.08164618909358978
# Cash on hand: 751690.5285428218
# Current portfolio value: 1044560.0626543066
# Current date: 1981-07-15 00:00:00+00:00
# Current portfolio value: 1052266.6464631385
# Current date: 1981-07-16 00:00:00+00:00
# Current portfolio value: 1059973.1500949985
# Current date: 1981-07-17 00:00:00+00:00
# Current portfolio value: 1070762.4048432834
# Current date: 1981-07-20 00:00:00+00:00
# Current portfolio value: 1049184.0289750001
# Current date: 1981-07-21 00:00:00+00:00
# Current portfolio value: 1047642.6266911305
# Current date: 1981-07-22 00:00:00+00:00
# Current portfolio value: 1030685.330772554
# Current date: 1981-07-23 00:00:00+00:00
# Current portfolio value: 1038394.9078550017
# Current date: 1981-07-24 00:00:00+00:00
# Current portfolio value: 1047642.6266911305
# Current date: 1981-07-27 00:00:00+00:00
# Current portfolio value: 1059973.1500949985
# Current date: 1981-07-28 00:00:00+00:00
# Current portfolio value: 1049184.0289750001
# Current date: 1981-07-29 00:00:00+00:00
# Current portfolio value: 1044560.0626543066
# Current date: 1981-07-30 00:00:00+00:00
# Current portfolio value: 1055349.1303229905
# Current date: 1981-07-31 00:00:00+00:00
# Current portfolio value: 1059973.1500949985
# Current date: 1981-08-03 00:00:00+00:00
# Current portfolio value: 1056890.4524298883
# Current date: 1981-08-04 00:00:00+00:00
# Current portfolio value: 1061514.445476239
# Current date: 1981-08-05 00:00:00+00:00
# Current portfolio value: 1070762.4048432834
# Current date: 1981-08-06 00:00:00+00:00
# Current portfolio value: 1063055.8477601088
# Current date: 1981-08-07 00:00:00+00:00
# Current portfolio value: 1063055.8477601088
# Current date: 1981-08-10 00:00:00+00:00
# Current portfolio value: 1063055.8477601088
# Current date: 1981-08-11 00:00:00+00:00
# Current portfolio value: 1053807.941844379
# Current date: 1981-08-12 00:00:00+00:00
# Current portfolio value: 1047642.6266911305
# Current date: 1981-08-13 00:00:00+00:00
# Current portfolio value: 1038394.9078550017
# Current date: 1981-08-14 00:00:00+00:00
# Current portfolio value: 1033770.72772905
# Current date: 1981-08-17 00:00:00+00:00
# Current portfolio value: 1024520.0957962773
# Current date: 1981-08-18 00:00:00+00:00
# Current portfolio value: 1018354.807368686
# Current date: 1981-08-19 00:00:00+00:00
# Current portfolio value: 1015272.2700575194
# Current date: 1981-08-20 00:00:00+00:00
# TIME TO BUY
# Buy price of AAPL: 0.07434068620204926
# Cash on hand: 751690.5285428218
# Current portfolio value: 1018354.807368686
# Current date: 1981-08-21 00:00:00+00:00
# TIME TO BUY
# Buy price of AAPL: 0.06918445974588394
# Cash on hand: 751690.5285428218
# Current portfolio value: 999859.129165513
# Current date: 1981-08-24 00:00:00+00:00
# TIME TO BUY
# Buy price of AAPL: 0.06488676369190216
# Cash on hand: 751690.5285428218
# Current portfolio value: 984443.0484512052
# Current date: 1981-08-25 00:00:00+00:00
# TIME TO BUY
# Buy price of AAPL: 0.06660633534193039
# Cash on hand: 751690.5285428218
# Current portfolio value: 990611.2499754406
# Current date: 1981-08-26 00:00:00+00:00
# TIME TO BUY
# Buy price of AAPL: 0.06531649827957153
# Cash on hand: 751690.5285428218
# Current portfolio value: 985984.5309120468
# Current date: 1981-08-27 00:00:00+00:00
# TIME TO BUY
# Buy price of AAPL: 0.06574618071317673
# Cash on hand: 751690.5285428218
# Current portfolio value: 987525.8262932873
# Current date: 1981-08-28 00:00:00+00:00
# TIME TO BUY
# Buy price of AAPL: 0.06918445974588394
# Cash on hand: 751690.5285428218
# Current portfolio value: 999859.129165513
# Current date: 1981-08-31 00:00:00+00:00
# TIME TO BUY
# Buy price of AAPL: 0.06918445974588394
# Cash on hand: 751690.5285428218
# Current portfolio value: 999859.129165513
# Current date: 1981-09-01 00:00:00+00:00
# TIME TO BUY
# Buy price of AAPL: 0.07348133623600006
# Cash on hand: 751690.5285428218
# Current portfolio value: 1015272.2700575194
# Current date: 1981-09-02 00:00:00+00:00
# Current portfolio value: 1019896.1562012411
# Current date: 1981-09-03 00:00:00+00:00
# Current portfolio value: 1006024.3106904752
# Current date: 1981-09-04 00:00:00+00:00
# Current portfolio value: 1002941.6664766795
# Current date: 1981-09-08 00:00:00+00:00
# Current portfolio value: 995235.1093935049
# Current date: 1981-09-09 00:00:00+00:00
# Current portfolio value: 995235.1093935049
# Current date: 1981-09-10 00:00:00+00:00
# Current portfolio value: 996776.4047747455
# Current date: 1981-09-11 00:00:00+00:00
# Current portfolio value: 993693.7872866071
# Current date: 1981-09-14 00:00:00+00:00
# Current portfolio value: 985984.5309120468
# Current date: 1981-09-15 00:00:00+00:00
# Current portfolio value: 979819.2157587982
# Current date: 1981-09-16 00:00:00+00:00
# Current portfolio value: 975195.1692611328
# Current date: 1981-09-17 00:00:00+00:00
# Current portfolio value: 969029.9342848561
# Current date: 1981-09-18 00:00:00+00:00
# Current portfolio value: 970571.2296660966
# Current date: 1981-09-21 00:00:00+00:00
# Current portfolio value: 972112.5384101658
# Current date: 1981-09-22 00:00:00+00:00
# Current portfolio value: 959782.0951832696
# Current date: 1981-09-23 00:00:00+00:00
# TIME TO BUY
# Buy price of AAPL: 0.05672270059585571
# Cash on hand: 751690.5285428218
# Current portfolio value: 955158.0887740902
# Current date: 1981-09-24 00:00:00+00:00
# TIME TO BUY
# Buy price of AAPL: 0.05629301443696022
# Cash on hand: 751690.5285428218
# Current portfolio value: 953616.780030021
# Current date: 1981-09-25 00:00:00+00:00
# TIME TO BUY
# Buy price of AAPL: 0.04898754879832268
# Cash on hand: 751690.5285428218
# Current portfolio value: 927411.6583726867
# Current date: 1981-09-28 00:00:00+00:00
# TIME TO BUY
# Buy price of AAPL: 0.04941723123192787
# Cash on hand: 751690.5285428218
# Current portfolio value: 928952.9537539273
# Current date: 1981-09-29 00:00:00+00:00
# TIME TO BUY
# Buy price of AAPL: 0.05199536681175232
# Cash on hand: 751690.5285428218
# Current portfolio value: 938200.8730324856
# Current date: 1981-09-30 00:00:00+00:00
# TIME TO BUY
# Buy price of AAPL: 0.05242506042122841
# Cash on hand: 751690.5285428218
# Current portfolio value: 939742.2085022121
# Current date: 1981-10-01 00:00:00+00:00
# TIME TO BUY
# Buy price of AAPL: 0.05242506042122841
# Cash on hand: 751690.5285428218
# Current portfolio value: 939742.2085022121
# Current date: 1981-10-02 00:00:00+00:00
# TIME TO BUY
# Buy price of AAPL: 0.05672270059585571
# Cash on hand: 751690.5285428218
# Current portfolio value: 955158.0887740902
# Current date: 1981-10-05 00:00:00+00:00
# Current portfolio value: 961323.3237503669
# Current date: 1981-10-06 00:00:00+00:00
# Current portfolio value: 959782.0951832696
# Current date: 1981-10-07 00:00:00+00:00
# Current portfolio value: 972112.5384101658
# Current date: 1981-10-08 00:00:00+00:00
# Current portfolio value: 979819.2157587982
# Current date: 1981-10-09 00:00:00+00:00
# Current portfolio value: 981360.4309630669
# Current date: 1981-10-12 00:00:00+00:00
# Current portfolio value: 989069.9278685427
# Current date: 1981-10-13 00:00:00+00:00
# Current portfolio value: 989069.9278685427
# Current date: 1981-10-14 00:00:00+00:00
# Current portfolio value: 975195.1692611328
# Current date: 1981-10-15 00:00:00+00:00
# Current portfolio value: 979819.2157587982
# Current date: 1981-10-16 00:00:00+00:00
# TIME TO SELL
# Sell price of AAPL: 0.06266303573548794
# Sold AAPL for 224775.88097623218
# Current portfolio value: 976466.409519054
# Current date: 1981-10-19 00:00:00+00:00
# TIME TO SELL
# AAPL not in portfolio
# Current portfolio value: 976466.409519054
# Current date: 1981-10-20 00:00:00+00:00
# TIME TO SELL
# AAPL not in portfolio
# Current portfolio value: 976466.409519054
# Current date: 1981-10-21 00:00:00+00:00
# TIME TO SELL
# AAPL not in portfolio
# Current portfolio value: 976466.409519054
# Current date: 1981-10-22 00:00:00+00:00
# TIME TO SELL
# AAPL not in portfolio
# Current portfolio value: 976466.409519054
# Current date: 1981-10-23 00:00:00+00:00
# Current portfolio value: 976466.409519054
# Current date: 1981-10-26 00:00:00+00:00
# Current portfolio value: 976466.409519054
# Current date: 1981-10-27 00:00:00+00:00
# Current portfolio value: 976466.409519054
# Current date: 1981-10-28 00:00:00+00:00
# Current portfolio value: 976466.409519054
# Current date: 1981-10-29 00:00:00+00:00
# Current portfolio value: 976466.409519054
# Current date: 1981-10-30 00:00:00+00:00
# Current portfolio value: 976466.409519054
# Current date: 1981-11-02 00:00:00+00:00
# Current portfolio value: 976466.409519054
# Current date: 1981-11-03 00:00:00+00:00
# Current portfolio value: 976466.409519054
# Current date: 1981-11-04 00:00:00+00:00
# Current portfolio value: 976466.409519054
# Current date: 1981-11-05 00:00:00+00:00
# Current portfolio value: 976466.409519054
# Current date: 1981-11-06 00:00:00+00:00
# Current portfolio value: 976466.409519054
# Current date: 1981-11-09 00:00:00+00:00
# Current portfolio value: 976466.409519054
# Current date: 1981-11-10 00:00:00+00:00
# Current portfolio value: 976466.409519054
# Current date: 1981-11-11 00:00:00+00:00
# Current portfolio value: 976466.409519054
# Current date: 1981-11-12 00:00:00+00:00
# Current portfolio value: 976466.409519054
# Current date: 1981-11-13 00:00:00+00:00
# Current portfolio value: 976466.409519054
# Current date: 1981-11-16 00:00:00+00:00
# Current portfolio value: 976466.409519054
# Current date: 1981-11-17 00:00:00+00:00
# Current portfolio value: 976466.409519054
# Current date: 1981-11-18 00:00:00+00:00
# Current portfolio value: 976466.409519054
# Current date: 1981-11-19 00:00:00+00:00
# Current portfolio value: 976466.409519054
# Current date: 1981-11-20 00:00:00+00:00
# Current portfolio value: 976466.409519054
# Current date: 1981-11-23 00:00:00+00:00
# Current portfolio value: 976466.409519054
# Current date: 1981-11-24 00:00:00+00:00
# Current portfolio value: 976466.409519054
# Current date: 1981-11-25 00:00:00+00:00
# Current portfolio value: 976466.409519054
# Current date: 1981-11-27 00:00:00+00:00
# Current portfolio value: 976466.409519054
# Current date: 1981-11-30 00:00:00+00:00
# Current portfolio value: 976466.409519054
# Current date: 1981-12-01 00:00:00+00:00
# Current portfolio value: 976466.409519054
# Current date: 1981-12-02 00:00:00+00:00
# Current portfolio value: 976466.409519054
# Current date: 1981-12-03 00:00:00+00:00
# Current portfolio value: 976466.409519054
# Current date: 1981-12-04 00:00:00+00:00
# Current portfolio value: 976466.409519054
# Current date: 1981-12-07 00:00:00+00:00
# Current portfolio value: 976466.409519054
# Current date: 1981-12-08 00:00:00+00:00
# Current portfolio value: 976466.409519054
# Current date: 1981-12-09 00:00:00+00:00
# Current portfolio value: 976466.409519054
# Current date: 1981-12-10 00:00:00+00:00
# Current portfolio value: 976466.409519054
# Current date: 1981-12-11 00:00:00+00:00
# Current portfolio value: 976466.409519054
# Current date: 1981-12-14 00:00:00+00:00
# Current portfolio value: 976466.409519054
# Current date: 1981-12-15 00:00:00+00:00
# Current portfolio value: 976466.409519054
# Current date: 1981-12-16 00:00:00+00:00
# Current portfolio value: 976466.409519054
# Current date: 1981-12-17 00:00:00+00:00
# Current portfolio value: 976466.409519054
# Current date: 1981-12-18 00:00:00+00:00
# Current portfolio value: 976466.409519054
# Current date: 1981-12-21 00:00:00+00:00
# TIME TO SELL
# AAPL not in portfolio
# Current portfolio value: 976466.409519054
# Current date: 1981-12-22 00:00:00+00:00
# Current portfolio value: 976466.409519054
# Current date: 1981-12-23 00:00:00+00:00
# Current portfolio value: 976466.409519054
# Current date: 1981-12-24 00:00:00+00:00
# Current portfolio value: 976466.409519054
# Current date: 1981-12-28 00:00:00+00:00
# Current portfolio value: 976466.409519054
# Current date: 1981-12-29 00:00:00+00:00
# Current portfolio value: 976466.409519054
# Current date: 1981-12-30 00:00:00+00:00
# Current portfolio value: 976466.409519054
# Current date: 1981-12-31 00:00:00+00:00
# Current portfolio value: 976466.409519054
# Current date: 1982-01-04 00:00:00+00:00
# Current portfolio value: 976466.409519054
# Current date: 1982-01-05 00:00:00+00:00
# Current portfolio value: 976466.409519054
# Current date: 1982-01-06 00:00:00+00:00
# Current portfolio value: 976466.409519054
# Current date: 1982-01-07 00:00:00+00:00
# Current portfolio value: 976466.409519054
# Current date: 1982-01-08 00:00:00+00:00
# Current portfolio value: 976466.409519054
# Current date: 1982-01-11 00:00:00+00:00
# Current portfolio value: 976466.409519054
# Current date: 1982-01-12 00:00:00+00:00
# Current portfolio value: 976466.409519054
# Current date: 1982-01-13 00:00:00+00:00
# Current portfolio value: 976466.409519054
# Current date: 1982-01-14 00:00:00+00:00
# Current portfolio value: 976466.409519054
# Current date: 1982-01-15 00:00:00+00:00
# Current portfolio value: 976466.409519054
# Current date: 1982-01-18 00:00:00+00:00
# Current portfolio value: 976466.409519054
# Current date: 1982-01-19 00:00:00+00:00
# Current portfolio value: 976466.409519054
# Current date: 1982-01-20 00:00:00+00:00
# Current portfolio value: 976466.409519054
# Current date: 1982-01-21 00:00:00+00:00
# Current portfolio value: 976466.409519054
# Current date: 1982-01-22 00:00:00+00:00
# Current portfolio value: 976466.409519054
# Current date: 1982-01-25 00:00:00+00:00
# Current portfolio value: 976466.409519054
# Current date: 1982-01-26 00:00:00+00:00
# Current portfolio value: 976466.409519054
# Current date: 1982-01-27 00:00:00+00:00
# Current portfolio value: 976466.409519054
# Current date: 1982-01-28 00:00:00+00:00
# Current portfolio value: 976466.409519054
# Current date: 1982-01-29 00:00:00+00:00
# Current portfolio value: 976466.409519054
# Current date: 1982-02-01 00:00:00+00:00
# Current portfolio value: 976466.409519054
# Current date: 1982-02-02 00:00:00+00:00
# Current portfolio value: 976466.409519054
# Current date: 1982-02-03 00:00:00+00:00
# Current portfolio value: 976466.409519054
# Current date: 1982-02-04 00:00:00+00:00
# Current portfolio value: 976466.409519054
# Current date: 1982-02-05 00:00:00+00:00
# Current portfolio value: 976466.409519054
# Current date: 1982-02-08 00:00:00+00:00
# Current portfolio value: 976466.409519054
# Current date: 1982-02-09 00:00:00+00:00
# Current portfolio value: 976466.409519054
# Current date: 1982-02-10 00:00:00+00:00
# Current portfolio value: 976466.409519054
# Current date: 1982-02-11 00:00:00+00:00
# Current portfolio value: 976466.409519054
# Current date: 1982-02-12 00:00:00+00:00
# Current portfolio value: 976466.409519054
# Current date: 1982-02-16 00:00:00+00:00
# Current portfolio value: 976466.409519054
# Current date: 1982-02-17 00:00:00+00:00
# Current portfolio value: 976466.409519054
# Current date: 1982-02-18 00:00:00+00:00
# Current portfolio value: 976466.409519054
# Current date: 1982-02-19 00:00:00+00:00
# Current portfolio value: 976466.409519054
# Current date: 1982-02-22 00:00:00+00:00
# Current portfolio value: 976466.409519054
# Current date: 1982-02-23 00:00:00+00:00
# Current portfolio value: 976466.409519054
# Current date: 1982-02-24 00:00:00+00:00
# TIME TO BUY
# Buy price of AAPL: 0.06316801905632019
# Cash on hand: 976466.409519054
# Bought AAPL for 292939.87517359864
# Current portfolio value: 976115.3029966726
# Current date: 1982-02-25 00:00:00+00:00
# Current portfolio value: 974124.9823257028
# Current date: 1982-02-26 00:00:00+00:00
# Current portfolio value: 974124.9823257028
# Current date: 1982-03-01 00:00:00+00:00
# Current portfolio value: 976115.3029966726
# Current date: 1982-03-02 00:00:00+00:00
# Current portfolio value: 976115.3029966726
# Current date: 1982-03-03 00:00:00+00:00
# Current portfolio value: 976115.3029966726
# Current date: 1982-03-04 00:00:00+00:00
# Current portfolio value: 970144.6515777333
# Current date: 1982-03-05 00:00:00+00:00
# Current portfolio value: 948251.5383223592
# Current date: 1982-03-08 00:00:00+00:00
# TIME TO BUY
# Buy price of AAPL: 0.05629301443696022
# Cash on hand: 683526.5343454554
# Current portfolio value: 944270.8797251991
# Current date: 1982-03-09 00:00:00+00:00
# TIME TO BUY
# Buy price of AAPL: 0.05672270059585571
# Cash on hand: 683526.5343454554
# Current portfolio value: 946261.1486305072
# Current date: 1982-03-10 00:00:00+00:00
# TIME TO BUY
# Buy price of AAPL: 0.05586337298154831
# Cash on hand: 683526.5343454554
# Current portfolio value: 942280.8178825377
# Current date: 1982-03-11 00:00:00+00:00
# TIME TO BUY
# Buy price of AAPL: 0.05586337298154831
# Cash on hand: 683526.5343454554
# Current portfolio value: 942280.8178825377
# Current date: 1982-03-12 00:00:00+00:00
# TIME TO BUY
# Buy price of AAPL: 0.05242506042122841
# Cash on hand: 683526.5343454554
# Current portfolio value: 926354.8532363287
# Current date: 1982-03-15 00:00:00+00:00
# TIME TO BUY
# Buy price of AAPL: 0.05199536681175232
# Cash on hand: 683526.5343454554
# Current portfolio value: 924364.5498205795
# Current date: 1982-03-16 00:00:00+00:00
# TIME TO BUY
# Buy price of AAPL: 0.05113598331809044
# Cash on hand: 683526.5343454554
# Current portfolio value: 920383.9602443016
# Current date: 1982-03-17 00:00:00+00:00
# TIME TO BUY
# Buy price of AAPL: 0.04855787009000778
# Cash on hand: 683526.5343454554
# Current portfolio value: 908442.3640676736
# Current date: 1982-03-18 00:00:00+00:00
# TIME TO BUY
# Buy price of AAPL: 0.05242506042122841
# Cash on hand: 683526.5343454554
# Current portfolio value: 926354.8532363287
# Current date: 1982-03-19 00:00:00+00:00
# TIME TO BUY
# Buy price of AAPL: 0.057152412831783295
# Cash on hand: 683526.5343454554
# Current portfolio value: 948251.5383223592
# Current date: 1982-03-22 00:00:00+00:00
# Current portfolio value: 968154.1756097785
# Current date: 1982-03-23 00:00:00+00:00
# Current portfolio value: 964173.6550543829
# Current date: 1982-03-24 00:00:00+00:00
# Current portfolio value: 948251.5383223592
# Current date: 1982-03-25 00:00:00+00:00
# Current portfolio value: 946261.1486305072
# Current date: 1982-03-26 00:00:00+00:00
# Current portfolio value: 942280.8178825377
# Current date: 1982-03-29 00:00:00+00:00
# Current portfolio value: 948251.5383223592
# Current date: 1982-03-30 00:00:00+00:00
# Current portfolio value: 952232.0588777548
# Current date: 1982-03-31 00:00:00+00:00
# Current portfolio value: 952232.0588777548
# Current date: 1982-04-01 00:00:00+00:00
# Current portfolio value: 966163.9067044704
# Current date: 1982-04-02 00:00:00+00:00
# Current portfolio value: 966163.9067044704
# Current date: 1982-04-05 00:00:00+00:00
# Current portfolio value: 966163.9067044704
# Current date: 1982-04-06 00:00:00+00:00
# Current portfolio value: 964173.6550543829
# Current date: 1982-04-07 00:00:00+00:00
# TIME TO SELL
# Sell price of AAPL: 0.059658868032693865
# Sold AAPL for 276334.68640591914
# Current portfolio value: 959861.2207513745
# Current date: 1982-04-08 00:00:00+00:00
# Current portfolio value: 959861.2207513745
# Current date: 1982-04-12 00:00:00+00:00
# Current portfolio value: 959861.2207513745
# Current date: 1982-04-13 00:00:00+00:00
# Current portfolio value: 959861.2207513745
# Current date: 1982-04-14 00:00:00+00:00
# Current portfolio value: 959861.2207513745
# Current date: 1982-04-15 00:00:00+00:00
# Current portfolio value: 959861.2207513745
# Current date: 1982-04-16 00:00:00+00:00
# Current portfolio value: 959861.2207513745
# Current date: 1982-04-19 00:00:00+00:00
# Current portfolio value: 959861.2207513745
# Current date: 1982-04-20 00:00:00+00:00
# Current portfolio value: 959861.2207513745
# Current date: 1982-04-21 00:00:00+00:00
# Current portfolio value: 959861.2207513745
# Current date: 1982-04-22 00:00:00+00:00
# Current portfolio value: 959861.2207513745
# Current date: 1982-04-23 00:00:00+00:00
# TIME TO BUY
# Buy price of AAPL: 0.0528547428548336
# Cash on hand: 959861.2207513745
# Bought AAPL for 287958.3417616171
# Current portfolio value: 959516.0849042771
# Current date: 1982-04-26 00:00:00+00:00
# TIME TO BUY
# Buy price of AAPL: 0.054144591093063354
# Cash on hand: 671902.8789897574
# AAPL has excess shares, reallocating portfolio
# 86280 of AAPL sold for 0.05407961758375168 to rebalance portfolio
# Current portfolio value: 966529.2887863835
# Current date: 1982-04-27 00:00:00+00:00
# Current portfolio value: 957320.6896185671
# Current date: 1982-04-28 00:00:00+00:00
# Current portfolio value: 945815.1426316445
# Current date: 1982-04-29 00:00:00+00:00
# Current portfolio value: 945815.1426316445
# Current date: 1982-04-30 00:00:00+00:00
# TIME TO BUY
# Buy price of AAPL: 0.050706297159194946
# Cash on hand: 676568.8683948835
# Current portfolio value: 948116.2001589258
# Current date: 1982-05-03 00:00:00+00:00
# Current portfolio value: 957320.6896185671
# Current date: 1982-05-04 00:00:00+00:00
# AAPL has excess shares, reallocating portfolio
# 31 of AAPL sold for 0.05407961758375168 to rebalance portfolio
# Current portfolio value: 966529.2867722047
# Current date: 1982-05-05 00:00:00+00:00
# Current portfolio value: 961922.8891740945
# Current date: 1982-05-06 00:00:00+00:00
# AAPL has excess shares, reallocating portfolio
# 58568 of AAPL sold for 0.054937947492301464 to rebalance portfolio
# Current portfolio value: 971127.5293708423
# Current date: 1982-05-07 00:00:00+00:00
# AAPL has excess shares, reallocating portfolio
# 57061 of AAPL sold for 0.05579633693397045 to rebalance portfolio
# Current portfolio value: 975675.7972358408
# Current date: 1982-05-10 00:00:00+00:00
# Current portfolio value: 971172.7436341512
# Current date: 1982-05-11 00:00:00+00:00
# Current portfolio value: 962163.0644221845
# Current date: 1982-05-12 00:00:00+00:00
# Current portfolio value: 955408.8451243433
# Current date: 1982-05-13 00:00:00+00:00
# Current portfolio value: 957660.2840889114
# Current date: 1982-05-14 00:00:00+00:00
# Current portfolio value: 946403.2259002792
# Current date: 1982-05-17 00:00:00+00:00
# Current portfolio value: 941900.3479711431
# Current date: 1982-05-18 00:00:00+00:00
# Current portfolio value: 937397.6066762152
# Current date: 1982-05-19 00:00:00+00:00
# Current portfolio value: 935146.1677116471
# Current date: 1982-05-20 00:00:00+00:00
# Current portfolio value: 937397.6066762152
# Current date: 1982-05-21 00:00:00+00:00
# Current portfolio value: 939648.9675640928
# Current date: 1982-05-24 00:00:00+00:00
# Current portfolio value: 941900.3479711431
# Current date: 1982-05-25 00:00:00+00:00
# Current portfolio value: 941900.3479711431
# Current date: 1982-05-26 00:00:00+00:00
# Current portfolio value: 939648.9675640928
# Current date: 1982-05-27 00:00:00+00:00
# TIME TO BUY
# Buy price of AAPL: 0.04812817648053169
# Cash on hand: 682971.945353547
# Current portfolio value: 935146.1677116471
# Current date: 1982-05-28 00:00:00+00:00
# TIME TO BUY
# Buy price of AAPL: 0.04812817648053169
# Cash on hand: 682971.945353547
# Current portfolio value: 935146.1677116471
# Current date: 1982-06-01 00:00:00+00:00
# TIME TO BUY
# Buy price of AAPL: 0.04726880416274071
# Cash on hand: 682971.945353547
# Current portfolio value: 930643.3678592014
# Current date: 1982-06-02 00:00:00+00:00
# TIME TO BUY
# Buy price of AAPL: 0.04812817648053169
# Cash on hand: 682971.945353547
# Current portfolio value: 935146.1677116471
# Current date: 1982-06-03 00:00:00+00:00
# Current portfolio value: 926140.5875259283
# Current date: 1982-06-04 00:00:00+00:00
# TIME TO BUY
# Buy price of AAPL: 0.04512033611536026
# Cash on hand: 682971.945353547
# Current portfolio value: 919386.173036361
# Current date: 1982-06-07 00:00:00+00:00
# TIME TO BUY
# Buy price of AAPL: 0.04512033611536026
# Cash on hand: 682971.945353547
# Current portfolio value: 919386.173036361
# Current date: 1982-06-08 00:00:00+00:00
# TIME TO BUY
# Buy price of AAPL: 0.04469068720936775
# Cash on hand: 682971.945353547
# Current portfolio value: 917134.9683018642
# Current date: 1982-06-09 00:00:00+00:00
# Current portfolio value: 912632.0903727281
# Current date: 1982-06-10 00:00:00+00:00
# TIME TO BUY
# Buy price of AAPL: 0.044260989874601364
# Cash on hand: 682971.945353547
# Current portfolio value: 914883.5098181235
# Current date: 1982-06-11 00:00:00+00:00
# TIME TO BUY
# Buy price of AAPL: 0.04597973823547363
# Cash on hand: 682971.945353547
# Current portfolio value: 923889.1290421876
# Current date: 1982-06-14 00:00:00+00:00
# Current portfolio value: 923889.1290421876
# Current date: 1982-06-15 00:00:00+00:00
# Current portfolio value: 923889.1290421876
# Current date: 1982-06-16 00:00:00+00:00
# Current portfolio value: 923889.1290421876
# Current date: 1982-06-17 00:00:00+00:00
# Current portfolio value: 919386.173036361
# Current date: 1982-06-18 00:00:00+00:00
# Current portfolio value: 914883.5098181235
# Current date: 1982-06-21 00:00:00+00:00
# Current portfolio value: 914883.5098181235
# Current date: 1982-06-22 00:00:00+00:00
# Current portfolio value: 923889.1290421876
# Current date: 1982-06-23 00:00:00+00:00
# Current portfolio value: 930643.3678592014
# Current date: 1982-06-24 00:00:00+00:00
# Current portfolio value: 930643.3678592014
# Current date: 1982-06-25 00:00:00+00:00
# Current portfolio value: 921637.7876734826
# Current date: 1982-06-28 00:00:00+00:00
# Current portfolio value: 919386.173036361
# Current date: 1982-06-29 00:00:00+00:00
# Current portfolio value: 912632.0903727281
# Current date: 1982-06-30 00:00:00+00:00
# Current portfolio value: 912632.0903727281
# Current date: 1982-07-01 00:00:00+00:00
# Current portfolio value: 910380.65140816
# Current date: 1982-07-02 00:00:00+00:00
# Current portfolio value: 899119.5137124526
# Current date: 1982-07-06 00:00:00+00:00
# Current portfolio value: 890113.8359308707
# Current date: 1982-07-07 00:00:00+00:00
# TIME TO BUY
# Buy price of AAPL: 0.03953362628817558
# Cash on hand: 682971.945353547
# Current portfolio value: 890113.8359308707
# Current date: 1982-07-08 00:00:00+00:00
# TIME TO BUY
# Buy price of AAPL: 0.037814877927303314
# Cash on hand: 682971.945353547
# Current portfolio value: 881108.2167068067
# Current date: 1982-07-09 00:00:00+00:00
# TIME TO BUY
# Buy price of AAPL: 0.03910394012928009
# Cash on hand: 682971.945353547
# Current portfolio value: 887862.4360046479
# Current date: 1982-07-12 00:00:00+00:00
# Current portfolio value: 892365.2748954388
# Current date: 1982-07-13 00:00:00+00:00
# Current portfolio value: 905877.812517369
# Current date: 1982-07-14 00:00:00+00:00
# Current portfolio value: 908129.2124435919
# Current date: 1982-07-15 00:00:00+00:00
# Current portfolio value: 912632.0903727281
# Current date: 1982-07-16 00:00:00+00:00
# Current portfolio value: 921637.7876734826
# Current date: 1982-07-19 00:00:00+00:00
# Current portfolio value: 923889.1290421876
# Current date: 1982-07-20 00:00:00+00:00
# Current portfolio value: 939648.9675640928
# Current date: 1982-07-21 00:00:00+00:00
# Current portfolio value: 939648.9675640928
# Current date: 1982-07-22 00:00:00+00:00
# Current portfolio value: 941900.3479711431
# Current date: 1982-07-23 00:00:00+00:00
# Current portfolio value: 937397.6066762152
# Current date: 1982-07-26 00:00:00+00:00
# Current portfolio value: 926140.5875259283
# Current date: 1982-07-27 00:00:00+00:00
# Current portfolio value: 926140.5875259283
# Current date: 1982-07-28 00:00:00+00:00
# Current portfolio value: 914883.5098181235
# Current date: 1982-07-29 00:00:00+00:00
# Current portfolio value: 923889.1290421876
# Current date: 1982-07-30 00:00:00+00:00
# Current portfolio value: 926140.5875259283
# Current date: 1982-08-02 00:00:00+00:00
# Current portfolio value: 932894.6701895612
# Current date: 1982-08-03 00:00:00+00:00
# Current portfolio value: 917134.9683018642
# Current date: 1982-08-04 00:00:00+00:00
# Current portfolio value: 914883.5098181235
# Current date: 1982-08-05 00:00:00+00:00
# Current portfolio value: 905877.812517369
# Current date: 1982-08-06 00:00:00+00:00
# Current portfolio value: 903626.4125911462
# Current date: 1982-08-09 00:00:00+00:00
# Current portfolio value: 905877.812517369
# Current date: 1982-08-10 00:00:00+00:00
# Current portfolio value: 919386.173036361
# Current date: 1982-08-11 00:00:00+00:00
# Current portfolio value: 921637.7876734826
# Current date: 1982-08-12 00:00:00+00:00
# Current portfolio value: 919386.173036361
# Current date: 1982-08-13 00:00:00+00:00
# Current portfolio value: 919386.173036361
# Current date: 1982-08-16 00:00:00+00:00
# Current portfolio value: 923889.1290421876
# Current date: 1982-08-17 00:00:00+00:00
# Current portfolio value: 939648.9675640928
# Current date: 1982-08-18 00:00:00+00:00
# Current portfolio value: 939648.9675640928
# Current date: 1982-08-19 00:00:00+00:00
# Current portfolio value: 941900.3479711431
# Current date: 1982-08-20 00:00:00+00:00
# Current portfolio value: 948654.5867881569
# Current date: 1982-08-23 00:00:00+00:00
# Current portfolio value: 959911.6644959616
# Current date: 1982-08-24 00:00:00+00:00
# TIME TO SELL
# Sell price of AAPL: 0.055367155236005786
# Sold AAPL for 290103.8505264749
# Current portfolio value: 973075.7958800219
# Current date: 1982-08-25 00:00:00+00:00
# TIME TO SELL
# AAPL not in portfolio
# Current portfolio value: 973075.7958800219
# Current date: 1982-08-26 00:00:00+00:00
# TIME TO SELL
# AAPL not in portfolio
# Current portfolio value: 973075.7958800219
# Current date: 1982-08-27 00:00:00+00:00
# TIME TO SELL
# AAPL not in portfolio
# Current portfolio value: 973075.7958800219
# Current date: 1982-08-30 00:00:00+00:00
# TIME TO SELL
# AAPL not in portfolio
# Current portfolio value: 973075.7958800219
# Current date: 1982-08-31 00:00:00+00:00
# TIME TO SELL
# AAPL not in portfolio
# Current portfolio value: 973075.7958800219
# Current date: 1982-09-01 00:00:00+00:00
# TIME TO SELL
# AAPL not in portfolio
# Current portfolio value: 973075.7958800219
# Current date: 1982-09-02 00:00:00+00:00
# TIME TO SELL
# AAPL not in portfolio
# Current portfolio value: 973075.7958800219
# Current date: 1982-09-03 00:00:00+00:00
# TIME TO SELL
# AAPL not in portfolio
# Current portfolio value: 973075.7958800219
# Current date: 1982-09-07 00:00:00+00:00
# TIME TO SELL
# AAPL not in portfolio
# Current portfolio value: 973075.7958800219
# Current date: 1982-09-08 00:00:00+00:00
# Current portfolio value: 973075.7958800219
# Current date: 1982-09-09 00:00:00+00:00
# Current portfolio value: 973075.7958800219
# Current date: 1982-09-10 00:00:00+00:00
# Current portfolio value: 973075.7958800219
# Current date: 1982-09-13 00:00:00+00:00
# Current portfolio value: 973075.7958800219
# Current date: 1982-09-14 00:00:00+00:00
# Current portfolio value: 973075.7958800219
# Current date: 1982-09-15 00:00:00+00:00
# Current portfolio value: 973075.7958800219
# Current date: 1982-09-16 00:00:00+00:00
# Current portfolio value: 973075.7958800219
# Current date: 1982-09-17 00:00:00+00:00
# Current portfolio value: 973075.7958800219
# Current date: 1982-09-20 00:00:00+00:00
# Current portfolio value: 973075.7958800219
# Current date: 1982-09-21 00:00:00+00:00
# Current portfolio value: 973075.7958800219
# Current date: 1982-09-22 00:00:00+00:00
# Current portfolio value: 973075.7958800219
# Current date: 1982-09-23 00:00:00+00:00
# Current portfolio value: 973075.7958800219
# Current date: 1982-09-24 00:00:00+00:00
# Current portfolio value: 973075.7958800219
# Current date: 1982-09-27 00:00:00+00:00
# Current portfolio value: 973075.7958800219
# Current date: 1982-09-28 00:00:00+00:00
# Current portfolio value: 973075.7958800219
# Current date: 1982-09-29 00:00:00+00:00
# Current portfolio value: 973075.7958800219
# Current date: 1982-09-30 00:00:00+00:00
# Current portfolio value: 973075.7958800219
# Current date: 1982-10-01 00:00:00+00:00
# Current portfolio value: 973075.7958800219
# Current date: 1982-10-04 00:00:00+00:00
# Current portfolio value: 973075.7958800219
# Current date: 1982-10-05 00:00:00+00:00
# Current portfolio value: 973075.7958800219
# Current date: 1982-10-06 00:00:00+00:00
# Current portfolio value: 973075.7958800219
# Current date: 1982-10-07 00:00:00+00:00
# Current portfolio value: 973075.7958800219
# Current date: 1982-10-08 00:00:00+00:00
# TIME TO SELL
# AAPL not in portfolio
# Current portfolio value: 973075.7958800219
# Current date: 1982-10-11 00:00:00+00:00
# TIME TO SELL
# AAPL not in portfolio
# Current portfolio value: 973075.7958800219
# Current date: 1982-10-12 00:00:00+00:00
# TIME TO SELL
# AAPL not in portfolio
# Current portfolio value: 973075.7958800219
# Current date: 1982-10-13 00:00:00+00:00
# TIME TO SELL
# AAPL not in portfolio
# Current portfolio value: 973075.7958800219
# Current date: 1982-10-14 00:00:00+00:00
# TIME TO SELL
# AAPL not in portfolio
# Current portfolio value: 973075.7958800219
# Current date: 1982-10-15 00:00:00+00:00
# TIME TO SELL
# AAPL not in portfolio
# Current portfolio value: 973075.7958800219
# Current date: 1982-10-18 00:00:00+00:00
# TIME TO SELL
# AAPL not in portfolio
# Current portfolio value: 973075.7958800219
# Current date: 1982-10-19 00:00:00+00:00
# TIME TO SELL
# AAPL not in portfolio
# Current portfolio value: 973075.7958800219
# Current date: 1982-10-20 00:00:00+00:00
# TIME TO SELL
# AAPL not in portfolio
# Current portfolio value: 973075.7958800219
# Current date: 1982-10-21 00:00:00+00:00
# TIME TO SELL
# AAPL not in portfolio
# Current portfolio value: 973075.7958800219
# Current date: 1982-10-22 00:00:00+00:00
# TIME TO SELL
# AAPL not in portfolio
# Current portfolio value: 973075.7958800219
# Current date: 1982-10-25 00:00:00+00:00
# TIME TO SELL
# AAPL not in portfolio
# Current portfolio value: 973075.7958800219
# Current date: 1982-10-26 00:00:00+00:00
# Current portfolio value: 973075.7958800219
# Current date: 1982-10-27 00:00:00+00:00
# Current portfolio value: 973075.7958800219
# Current date: 1982-10-28 00:00:00+00:00
# Current portfolio value: 973075.7958800219
# Current date: 1982-10-29 00:00:00+00:00
# Current portfolio value: 973075.7958800219
# Current date: 1982-11-01 00:00:00+00:00
# Current portfolio value: 973075.7958800219
# Current date: 1982-11-02 00:00:00+00:00
# Current portfolio value: 973075.7958800219
# Current date: 1982-11-03 00:00:00+00:00
# TIME TO SELL
# AAPL not in portfolio
# Current portfolio value: 973075.7958800219
# Current date: 1982-11-04 00:00:00+00:00
# TIME TO SELL
# AAPL not in portfolio
# Current portfolio value: 973075.7958800219
# Current date: 1982-11-05 00:00:00+00:00
# TIME TO SELL
# AAPL not in portfolio
# Current portfolio value: 973075.7958800219
# Current date: 1982-11-08 00:00:00+00:00
# TIME TO SELL
# AAPL not in portfolio
# Current portfolio value: 973075.7958800219
# Current date: 1982-11-09 00:00:00+00:00
# Current portfolio value: 973075.7958800219
# Current date: 1982-11-10 00:00:00+00:00
# Current portfolio value: 973075.7958800219
# Current date: 1982-11-11 00:00:00+00:00
# Current portfolio value: 973075.7958800219
# Current date: 1982-11-12 00:00:00+00:00
# Current portfolio value: 973075.7958800219
# Current date: 1982-11-15 00:00:00+00:00
# TIME TO SELL
# AAPL not in portfolio
# Current portfolio value: 973075.7958800219
# Current date: 1982-11-16 00:00:00+00:00
# TIME TO SELL
# AAPL not in portfolio
# Current portfolio value: 973075.7958800219
# Current date: 1982-11-17 00:00:00+00:00
# Current portfolio value: 973075.7958800219
# Current date: 1982-11-18 00:00:00+00:00
# Current portfolio value: 973075.7958800219
# Current date: 1982-11-19 00:00:00+00:00
# Current portfolio value: 973075.7958800219
# Current date: 1982-11-22 00:00:00+00:00
# Current portfolio value: 973075.7958800219
# Current date: 1982-11-23 00:00:00+00:00
# Current portfolio value: 973075.7958800219
# Current date: 1982-11-24 00:00:00+00:00
# Current portfolio value: 973075.7958800219
# Current date: 1982-11-26 00:00:00+00:00
# Current portfolio value: 973075.7958800219
# Current date: 1982-11-29 00:00:00+00:00
# Current portfolio value: 973075.7958800219
# Current date: 1982-11-30 00:00:00+00:00
# Current portfolio value: 973075.7958800219
# Current date: 1982-12-01 00:00:00+00:00
# Current portfolio value: 973075.7958800219
# ...
# Current portfolio value: 29327651.118127435
# Current date: 2023-07-27 00:00:00+00:00
# Current portfolio value: 29327651.118127435
# Current date: 2023-07-28 00:00:00+00:00
# Current portfolio value: 29327651.118127435
# Current date: 2023-07-31 00:00:00+00:00
# TIME TO SELL
# GOOG not in portfolio
# Current portfolio value: 29327651.118127435
# Current date: 2023-08-01 00:00:00+00:00
# TIME TO SELL
# GOOG not in portfolio
# Current portfolio value: 29327651.118127435
# Current date: 2023-08-02 00:00:00+00:00
# Current portfolio value: 29327651.118127435
# Current date: 2023-08-03 00:00:00+00:00
# Current portfolio value: 29327651.118127435
# Current date: 2023-08-04 00:00:00+00:00
# Current portfolio value: 29327651.118127435
# Current date: 2023-08-07 00:00:00+00:00
# Current portfolio value: 29327651.118127435
# Current date: 2023-08-08 00:00:00+00:00
# TIME TO BUY
# Buy price of AAPL: 178.44705200195312
# Cash on hand: 29327651.118127435
# Bought AAPL for 8798170.225927183
# Current portfolio value: 29317105.968036436
# Current date: 2023-08-09 00:00:00+00:00
# TIME TO BUY
# Buy price of AAPL: 176.84918212890625
# Cash on hand: 20529480.892200254
# Current portfolio value: 29238418.866138242
# Current date: 2023-08-10 00:00:00+00:00
# TIME TO BUY
# Buy price of AAPL: 176.6308135986328
# Cash on hand: 20529480.892200254
# Current portfolio value: 29227665.307864927
# Current date: 2023-08-11 00:00:00+00:00
# TIME TO BUY
# Buy price of AAPL: 176.69046020507812
# Cash on hand: 20529480.892200254
# Current portfolio value: 29230602.604999326
# Current date: 2023-08-14 00:00:00+00:00
# TIME TO BUY
# Buy price of AAPL: 178.3501434326172
# Cash on hand: 20529480.892200254
# Current portfolio value: 29312333.705539487
# Current date: 2023-08-15 00:00:00+00:00
# TIME TO BUY
# Buy price of AAPL: 176.35255432128906
# Cash on hand: 20529480.892200254
# Current portfolio value: 29213962.429752134
# Current date: 2023-08-16 00:00:00+00:00
# TIME TO BUY
# Buy price of AAPL: 175.47802734375
# Cash on hand: 20529480.892200254
# Current portfolio value: 29170896.348743223
# Current date: 2023-08-17 00:00:00+00:00
# TIME TO BUY
# Buy price of AAPL: 172.92388916015625
# Cash on hand: 20529480.892200254
# Current portfolio value: 29045117.81389215
# Current date: 2023-08-18 00:00:00+00:00
# TIME TO BUY
# Buy price of MSFT: 314.1222229003906
# Cash on hand: 20529480.892200254
# Bought MSFT for 5132311.948178087
# TIME TO BUY
# Buy price of AAPL: 173.410888671875
# Cash on hand: 15397168.944022167
# TIME TO BUY
# Buy price of META: 282.3997497558594
# Cash on hand: 15397168.944022167
# Bought META for 3849203.7014080803
# TIME TO BUY
# Buy price of TSLA: 215.49000549316406
# Cash on hand: 11547965.242614087
# Bought TSLA for 2886931.929620233
# Current portfolio value: 29054875.03783211
# Current date: 2023-08-21 00:00:00+00:00
# TIME TO BUY
# Buy price of MSFT: 319.4819641113281
# Cash on hand: 8661033.312993854
# TIME TO BUY
# Buy price of AAPL: 174.7525177001953
# Cash on hand: 8661033.312993854
# TIME TO BUY
# Buy price of META: 289.0297546386719
# Cash on hand: 8661033.312993854
# TIME TO BUY
# Buy price of TSLA: 231.27999877929688
# Cash on hand: 8661033.312993854
# Current portfolio value: 29509955.962789387
# Current date: 2023-08-22 00:00:00+00:00
# TIME TO BUY
# Buy price of AAPL: 176.13392639160156
# Cash on hand: 8661033.312993854
# Current portfolio value: 29581717.136922687
# Current date: 2023-08-23 00:00:00+00:00
# TIME TO BUY
# Buy price of AAPL: 179.9998779296875
# Cash on hand: 8661033.312993854
# Current portfolio value: 29984866.62315926
# Current date: 2023-08-24 00:00:00+00:00
# Current portfolio value: 29446099.864232868
# Current date: 2023-08-25 00:00:00+00:00
# Current portfolio value: 29701431.885579914
# Current date: 2023-08-28 00:00:00+00:00
# Current portfolio value: 29858106.664266437
# Current date: 2023-08-29 00:00:00+00:00
# Current portfolio value: 30477326.938451618
# Current date: 2023-08-30 00:00:00+00:00
# Current portfolio value: 30613269.01463875
# Current date: 2023-08-31 00:00:00+00:00
# AAPL has excess shares, reallocating portfolio
# 23 of AAPL sold for 186.48408012695313 to rebalance portfolio
# Current portfolio value: 30633860.147306744
# Current date: 2023-09-01 00:00:00+00:00
# TIME TO SELL
# NVDA not in portfolio
# AAPL has excess shares, reallocating portfolio
# 534 of AAPL sold for 188.0623383605957 to rebalance portfolio
# Current portfolio value: 30557856.51062204
# Current date: 2023-09-05 00:00:00+00:00
# Current portfolio value: 30853458.671587005
# Current date: 2023-09-06 00:00:00+00:00
# Current portfolio value: 30439608.082521453
# Current date: 2023-09-07 00:00:00+00:00
# Current portfolio value: 30120091.53390695
# Current date: 2023-09-08 00:00:00+00:00
# Current portfolio value: 30170114.01753427
# Current date: 2023-09-11 00:00:00+00:00
# Current portfolio value: 30753503.936723724
# Current date: 2023-09-12 00:00:00+00:00
# Current portfolio value: 30343796.240037933
# Current date: 2023-09-13 00:00:00+00:00
# Current portfolio value: 30409419.336656585
# Current date: 2023-09-14 00:00:00+00:00
# Current portfolio value: 30680034.94899179
# Current date: 2023-09-15 00:00:00+00:00
# TIME TO SELL
# AMZN not in portfolio
# TIME TO SELL
# GOOG not in portfolio
# TIME TO SELL
# Sell price of META: 299.0491876098633
# Sold META for 4071255.6401206786
# Current portfolio value: 30325518.091553874
# Current date: 2023-09-18 00:00:00+00:00
# Current portfolio value: 30328052.368134685
# Current date: 2023-09-19 00:00:00+00:00
# Current portfolio value: 30390963.39706535
# Current date: 2023-09-20 00:00:00+00:00
# TIME TO BUY
# Buy price of NVDA: 42.226226806640625
# Cash on hand: 12837003.37564201
# Bought NVDA for 9117266.775214745
# NVDA has excess shares, reallocating portfolio
# 2328 of NVDA sold for 42.175555334472655 to rebalance portfolio
# Current portfolio value: 30026737.05441535
# Current date: 2023-09-21 00:00:00+00:00
# TIME TO BUY
# Buy price of NVDA: 41.00459671020508
# Cash on hand: 3817921.2932459167
# Current portfolio value: 29578365.187029485
# Current date: 2023-09-22 00:00:00+00:00
# TIME TO BUY
# Buy price of NVDA: 41.597412109375
# Cash on hand: 3817921.2932459167
# NVDA has excess shares, reallocating portfolio
# 136 of NVDA sold for 41.54749521484375 to rebalance portfolio
# Current portfolio value: 29560835.462891765
# Current date: 2023-09-25 00:00:00+00:00
# TIME TO BUY
# Buy price of NVDA: 42.209232330322266
# Cash on hand: 3823571.7525951355
# NVDA has excess shares, reallocating portfolio
# 1458 of NVDA sold for 42.15858125152588 to rebalance portfolio
# Current portfolio value: 29790435.64613536
# Current date: 2023-09-26 00:00:00+00:00
# TIME TO BUY
# Buy price of NVDA: 41.89832305908203
# Cash on hand: 3885038.9640598604
# NVDA has excess shares, reallocating portfolio
# 1229 of NVDA sold for 41.848045071411136 to rebalance portfolio
# Current portfolio value: 29399320.176273488
# Current date: 2023-09-27 00:00:00+00:00
# TIME TO BUY
# Buy price of NVDA: 42.45515441894531
# Cash on hand: 3936470.2114526248
# NVDA has excess shares, reallocating portfolio
# 2724 of NVDA sold for 42.40420823364258 to rebalance portfolio
# Current portfolio value: 29404453.627174355
# Current date: 2023-09-28 00:00:00+00:00
# NVDA has excess shares, reallocating portfolio
# 1366 of NVDA sold for 43.02427472229004 to rebalance portfolio
# Current portfolio value: 29638404.955031734
# Current date: 2023-09-29 00:00:00+00:00
# NVDA has excess shares, reallocating portfolio
# 599 of NVDA sold for 43.43366064605713 to rebalance portfolio
# Current portfolio value: 29833699.19420678
# Current date: 2023-10-02 00:00:00+00:00
# TIME TO BUY
# Buy price of MSFT: 319.4025573730469
# Cash on hand: 4136767.1966787037
# TIME TO BUY
# Buy price of AMZN: 129.4600067138672
# Cash on hand: 4136767.1966787037
# Bought AMZN for 2068272.279125738
# NVDA has excess shares, reallocating portfolio
# 2540 of NVDA sold for 44.71473335876465 to rebalance portfolio
# Current portfolio value: 30334428.337430835
# Current date: 2023-10-03 00:00:00+00:00
# Current portfolio value: 29732340.654813647
# Current date: 2023-10-04 00:00:00+00:00
# TIME TO BUY
# Buy price of AMZN: 127.0
# Cash on hand: 2182070.340284228
# Current portfolio value: 30222160.089719653
# Current date: 2023-10-05 00:00:00+00:00
# TIME TO BUY
# Buy price of AMZN: 125.95999908447266
# Cash on hand: 2182070.340284228
# Current portfolio value: 30389152.083272815
# Current date: 2023-10-06 00:00:00+00:00
# NVDA has excess shares, reallocating portfolio
# 655 of NVDA sold for 45.69325971221924 to rebalance portfolio
# Current portfolio value: 30898504.99907661
# Current date: 2023-10-09 00:00:00+00:00
# Current portfolio value: 30906778.230842356
# Current date: 2023-10-10 00:00:00+00:00
# Current portfolio value: 31033250.32863975
# Current date: 2023-10-11 00:00:00+00:00
# NVDA has excess shares, reallocating portfolio
# 1304 of NVDA sold for 46.735693202209475 to rebalance portfolio
# Current portfolio value: 31399926.886400655
# Current date: 2023-10-12 00:00:00+00:00
# TIME TO SELL
# Sell price of NVDA: 46.87448442993164
# Sold NVDA for 9436630.581980549
# TIME TO SELL
# META not in portfolio
# Current portfolio value: 31393036.92652253
# Current date: 2023-10-13 00:00:00+00:00
# TIME TO SELL
# NVDA not in portfolio
# Current portfolio value: 31103246.501290597
# Current date: 2023-10-16 00:00:00+00:00
# Current portfolio value: 31257993.743127145
# Current date: 2023-10-17 00:00:00+00:00
# Current portfolio value: 31167841.491967477
# Current date: 2023-10-18 00:00:00+00:00
# Current portfolio value: 30856726.11174897
# Current date: 2023-10-19 00:00:00+00:00
# Current portfolio value: 30560238.416116036
# Current date: 2023-10-20 00:00:00+00:00
# Current portfolio value: 30199888.180901803
# Current date: 2023-10-23 00:00:00+00:00
# Current portfolio value: 30272001.595162667
# Current date: 2023-10-24 00:00:00+00:00
# Current portfolio value: 30404216.8026822
# Current date: 2023-10-25 00:00:00+00:00
# TIME TO BUY
# Buy price of TSLA: 212.4199981689453
# Cash on hand: 11709573.351311961
# Current portfolio value: 30285959.31716279
# Current date: 2023-10-26 00:00:00+00:00
# TIME TO BUY
# Buy price of TSLA: 205.75999450683594
# Cash on hand: 11709573.351311961
# Current portfolio value: 29757087.698487557
# Current date: 2023-10-27 00:00:00+00:00
# TIME TO BUY
# Buy price of AAPL: 167.17965698242188
# Cash on hand: 11709573.351311961
# TIME TO BUY
# Buy price of TSLA: 207.3000030517578
# Cash on hand: 11709573.351311961
# Current portfolio value: 30003516.540360726
# Current date: 2023-10-30 00:00:00+00:00
# TIME TO BUY
# Buy price of AAPL: 169.23683166503906
# Cash on hand: 11709573.351311961
# TIME TO BUY
# Buy price of TSLA: 197.36000061035156
# Cash on hand: 11709573.351311961
# Current portfolio value: 30171455.653893746
# Current date: 2023-10-31 00:00:00+00:00
# TIME TO BUY
# Buy price of TSLA: 200.83999633789062
# Cash on hand: 11709573.351311961
# Current portfolio value: 30260270.005212106
# Current date: 2023-11-01 00:00:00+00:00
# TIME TO BUY
# Buy price of GOOG: 127.25747680664062
# Cash on hand: 11709573.351311961
# Bought GOOG for 5854752.856907812
# TIME TO BUY
# Buy price of TSLA: 205.66000366210938
# Cash on hand: 5854820.494404149
# Current portfolio value: 30663911.748951267
# Current date: 2023-11-02 00:00:00+00:00
# TIME TO BUY
# Buy price of TSLA: 218.50999450683594
# Cash on hand: 5854820.494404149
# Current portfolio value: 31109866.27905686
# Current date: 2023-11-03 00:00:00+00:00
# Current portfolio value: 31247825.34189255
# Current date: 2023-11-06 00:00:00+00:00
# Current portfolio value: 31491545.22020371
# Current date: 2023-11-07 00:00:00+00:00
# Current portfolio value: 31811536.90555222
# Current date: 2023-11-08 00:00:00+00:00
# Current portfolio value: 31934989.929035496
# Current date: 2023-11-09 00:00:00+00:00
# Current portfolio value: 31613211.750004124
# Current date: 2023-11-10 00:00:00+00:00
# TIME TO SELL
# Sell price of MSFT: 366.4756249633789
# Sold MSFT for 5980515.72377738
# Current portfolio value: 32174787.40290443
# Current date: 2023-11-13 00:00:00+00:00
# TIME TO SELL
# MSFT not in portfolio
# Current portfolio value: 32183766.882503428
# Current date: 2023-11-14 00:00:00+00:00
# Current portfolio value: 32628271.162746347
# Current date: 2023-11-15 00:00:00+00:00
# TIME TO SELL
# Sell price of AAPL: 186.86891744995117
# Sold AAPL for 9098273.852803223
# TIME TO SELL
# NVDA not in portfolio
# TIME TO SELL
# Sell price of AMZN: 143.0281569519043
# Sold AMZN for 2282300.300481537
# TIME TO SELL
# META not in portfolio
# Current portfolio value: 32716933.4874636
# Current date: 2023-11-16 00:00:00+00:00
# TIME TO SELL
# MSFT not in portfolio
# TIME TO SELL
# AAPL not in portfolio
# TIME TO SELL
# NVDA not in portfolio
# TIME TO SELL
# AMZN not in portfolio
# TIME TO SELL
# Sell price of GOOG: 138.19418197631836
# Sold GOOG for 6350299.050175781
# TIME TO SELL
# META not in portfolio
# Current portfolio value: 32691877.162639383
# Current date: 2023-11-17 00:00:00+00:00
# TIME TO SELL
# MSFT not in portfolio
# TIME TO SELL
# AAPL not in portfolio
# TIME TO SELL
# NVDA not in portfolio
# TIME TO SELL
# AMZN not in portfolio
# TIME TO SELL
# GOOG not in portfolio
# TIME TO SELL
# META not in portfolio
# Current portfolio value: 32701377.76247764
# Current date: 2023-11-20 00:00:00+00:00
# TIME TO SELL
# MSFT not in portfolio
# TIME TO SELL
# AAPL not in portfolio
# TIME TO SELL
# NVDA not in portfolio
# TIME TO SELL
# AMZN not in portfolio
# TIME TO SELL
# GOOG not in portfolio
# TIME TO SELL
# META not in portfolio
# Current portfolio value: 32718773.10331321
# Current date: 2023-11-21 00:00:00+00:00
# TIME TO SELL
# MSFT not in portfolio
# TIME TO SELL
# AAPL not in portfolio
# TIME TO SELL
# NVDA not in portfolio
# TIME TO SELL
# AMZN not in portfolio
# TIME TO SELL
# GOOG not in portfolio
# TIME TO SELL
# META not in portfolio
# Current portfolio value: 32793706.580806497
# Current date: 2023-11-22 00:00:00+00:00
# TIME TO SELL
# AAPL not in portfolio
# TIME TO SELL
# NVDA not in portfolio
# TIME TO SELL
# GOOG not in portfolio
# TIME TO SELL
# META not in portfolio
# Current portfolio value: 32700173.521480326
# Current date: 2023-11-24 00:00:00+00:00
# TIME TO SELL
# AAPL not in portfolio
# TIME TO SELL
# GOOG not in portfolio
# TIME TO SELL
# META not in portfolio
# Current portfolio value: 32716765.830806497
# Current date: 2023-11-27 00:00:00+00:00
# TIME TO SELL
# AAPL not in portfolio
# TIME TO SELL
# META not in portfolio
# Current portfolio value: 32725195.92614341
# Current date: 2023-11-28 00:00:00+00:00
# TIME TO SELL
# AAPL not in portfolio
# Current portfolio value: 32867569.757976297
# Current date: 2023-11-29 00:00:00+00:00
# Current portfolio value: 32833046.753474955
# Current date: 2023-11-30 00:00:00+00:00
# Current portfolio value: 32778719.92614341
# Current date: 2023-12-01 00:00:00+00:00
# Current portfolio value: 32761993.67614341
# Current date: 2023-12-04 00:00:00+00:00
# Current portfolio value: 32718505.42614341
# Current date: 2023-12-05 00:00:00+00:00
# Current portfolio value: 32760521.757976297
# Current date: 2023-12-06 00:00:00+00:00
# Current portfolio value: 32769219.326305155
# Current date: 2023-12-07 00:00:00+00:00
# Current portfolio value: 32812975.253474955
# Current date: 2023-12-08 00:00:00+00:00
# Current portfolio value: 32829032.412639383
# Current date: 2023-12-11 00:00:00+00:00
# Current portfolio value: 32774170.435146097
# Current date: 2023-12-12 00:00:00+00:00
# Current portfolio value: 32737640.15813804
# Current date: 2023-12-13 00:00:00+00:00
# Current portfolio value: 32768148.821803812
# Current date: 2023-12-14 00:00:00+00:00
# Current portfolio value: 32925509.51247764
# Current date: 2023-12-15 00:00:00+00:00
# Current portfolio value: 32958292.92164207
# Current date: 2023-12-18 00:00:00+00:00
# Current portfolio value: 32939291.92614341
# Current date: 2023-12-19 00:00:00+00:00
# Current portfolio value: 33008070.257976297
# Current date: 2023-12-20 00:00:00+00:00
# Current portfolio value: 32873189.753474955
# Current date: 2023-12-21 00:00:00+00:00
# Current portfolio value: 32971673.92164207
# Current date: 2023-12-22 00:00:00+00:00
# Current portfolio value: 32945447.071803812
# Current date: 2023-12-26 00:00:00+00:00
# TIME TO SELL
# META not in portfolio
# Current portfolio value: 32999907.635631327
# Current date: 2023-12-27 00:00:00+00:00
# TIME TO SELL
# META not in portfolio
# Current portfolio value: 33064538.094310526
# Current date: 2023-12-28 00:00:00+00:00
# TIME TO SELL
# META not in portfolio
# Current portfolio value: 32954010.903636698
# Current date: 2023-12-29 00:00:00+00:00
# TIME TO SELL
# META not in portfolio
# Current portfolio value: 32891120.24447227

# %%
# Calculate performance metrics
portfolio_history = pd.Series(portfolio_history, index=combined_data_signalled.index[(combined_data_signalled.index >= BACKTEST_START_DATE) & (combined_data_signalled.index <= BACKTEST_END_DATE)])
total_return = (portfolio_value - INITIAL_CAPITAL) / INITIAL_CAPITAL
annual_return = (1 + total_return) ** (TRADING_DAYS_PER_YEAR / len(portfolio_history)) - 1
daily_returns = portfolio_history.pct_change().dropna()
annual_volatility = daily_returns.std() * np.sqrt(TRADING_DAYS_PER_YEAR)
max_drawdown = (portfolio_history / portfolio_history.cummax() - 1).min()

excess_daily_returns = daily_returns - (RISK_FREE_RATE / TRADING_DAYS_PER_YEAR)
sharpe_ratio = np.sqrt(TRADING_DAYS_PER_YEAR) * (excess_daily_returns.mean() / excess_daily_returns.std())
downside_returns = excess_daily_returns[excess_daily_returns < 0]
sortino_ratio = np.sqrt(TRADING_DAYS_PER_YEAR) * (excess_daily_returns.mean() / downside_returns.std())
average_return_per_trade = np.mean(trade_returns)
win_rate = wins / trade_count if trade_count > 0 else 0
expectancy = np.mean([r for r in trade_returns if r > 0]) * win_rate - (1 - win_rate) * np.mean([r for r in trade_returns if r < 0])

# Print the metrics
print(f"Total Return: {total_return:.2%}")
print(f"Annual Return: {annual_return:.2%}")
print(f"Annual Volatility: {annual_volatility:.2%}")
print(f"Maximum Drawdown: {max_drawdown:.2%}")
print(f"Sharpe Ratio: {sharpe_ratio:.2f}")
print(f"Sortino Ratio: {sortino_ratio:.2f}")
print(f"Total Number of Trades: {trade_count}")
print(f"Average Return per Trade: {average_return_per_trade:.2f}")
print(f"Win Rate: {win_rate:.2%}")
print(f"Expectancy: {expectancy:.2f}")
# Out:
# Total Return: 3189.11%
# Annual Return: 8.46%
# Annual Volatility: 17.67%
# Maximum Drawdown: -50.85%
# Sharpe Ratio: 0.43
# Sortino Ratio: 0.58
# Total Number of Trades: 627
# Average Return per Trade: 4.60
# Win Rate: 37.96%
# Expectancy: 2.64

# %% [markdown]
# ## Questions

# %% [markdown]
# ### 1. Which month did the portfolio have the highest return, and which stock contributed the most to that return?

# %%
# Resample data into monthly returns
monthly_returns = portfolio_history.resample('ME').ffill().pct_change().dropna()

max_return_month = monthly_returns.idxmax()
highest_monthly_return = monthly_returns[max_return_month]

# print(max_return_month)
print(f"The month with the highest return is October 2001, with a return of {highest_monthly_return:.2%}.")

start_date = max_return_month.replace(day=1)
end_date = (start_date + pd.offsets.MonthEnd()).normalize()

stock_returns = {}
for stock in symbol_list:
    start_price = combined_data_signalled.loc[start_date, (stock, 'Close')][stock]
    end_price = combined_data_signalled.loc[end_date, (stock, 'Close')][stock]
    stock_returns[stock] = (end_price - start_price) / start_price if start_price != 0 else 0

top_stock = max(stock_returns, key=stock_returns.get)
print(f"The stock with the highest contribution in October 2001 is {top_stock}, with a return of {stock_returns[top_stock]:.2%}.")
# Out:
# The month with the highest return is October 2001, with a return of 31.06%.
# The stock with the highest contribution in October 2001 is NVDA, with a return of 70.49%.

# %% [markdown]
# ### 2. Did the portfolio outperform the S&P 500? If so, what is your rationale for the outperformance?

# %%
# Fetch S&P 500 data
sp500_data = yf.download('^GSPC', start=BACKTEST_START_DATE, end=BACKTEST_END_DATE)
sp500_returns = sp500_data['Adj Close'].pct_change().dropna()['^GSPC']
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
RISK_FREE_RATE = 0.02
TRADING_DAYS_PER_YEAR = 252

# Total Return
sp500_total_return = (sp500_data['Close'].iloc[-1] / sp500_data['Close'].iloc[0]) - 1
sp500_total_return = sp500_total_return['^GSPC']

# Annual Return
sp500_annual_return = (1 + sp500_total_return) ** (TRADING_DAYS_PER_YEAR / len(sp500_returns)) - 1

# Annual Volatility
sp500_annual_volatility = sp500_returns.std() * np.sqrt(TRADING_DAYS_PER_YEAR)

# Maximum Drawdown
cumulative_returns = (1 + sp500_returns).cumprod()
sp500_max_drawdown = (cumulative_returns / cumulative_returns.cummax() - 1).min()

# Sharpe Ratio
sp500_excess_returns = sp500_returns - (RISK_FREE_RATE / TRADING_DAYS_PER_YEAR)
sp500_sharpe_ratio = np.sqrt(TRADING_DAYS_PER_YEAR) * (sp500_excess_returns.mean() / sp500_excess_returns.std())

# Sortino Ratio
sp500_downside_returns = sp500_excess_returns[sp500_excess_returns < 0]
sp500_sortino_ratio = np.sqrt(TRADING_DAYS_PER_YEAR) * (sp500_excess_returns.mean() / sp500_downside_returns.std())

print(f"S&P 500 Total Return: {sp500_total_return:.2%}")
print(f"S&P 500 Annual Return: {sp500_annual_return:.2%}")
print(f"S&P 500 Annual Volatility: {sp500_annual_volatility:.2%}")
print(f"S&P 500 Maximum Drawdown: {sp500_max_drawdown:.2%}")
print(f"S&P 500 Sharpe Ratio: {sp500_sharpe_ratio:.2f}")
print(f"S&P 500 Sortino Ratio: {sp500_sortino_ratio:.2f}")
print("\n")
print(f"Portfolio Total Return: {total_return:.2%}")
print(f"Portfolio Annual Return: {annual_return:.2%}")
print(f"Portfolio Annual Volatility: {annual_volatility:.2%}")
print(f"Portfolio Maximum Drawdown: {max_drawdown:.2%}")
print(f"Portfolio Sharpe Ratio: {sharpe_ratio:.2f}")
print(f"Portfolio Sortino Ratio: {sortino_ratio:.2f}")
# Out:
# S&P 500 Total Return: 3398.48%
# S&P 500 Annual Return: 8.62%
# S&P 500 Annual Volatility: 17.97%
# S&P 500 Maximum Drawdown: -56.78%
# S&P 500 Sharpe Ratio: 0.44
# S&P 500 Sortino Ratio: 0.55
#
#
# Portfolio Total Return: 3189.11%
# Portfolio Annual Return: 8.46%
# Portfolio Annual Volatility: 17.67%
# Portfolio Maximum Drawdown: -50.85%
# Portfolio Sharpe Ratio: 0.43
# Portfolio Sortino Ratio: 0.58

# %% [markdown]
# The portfolio slightly underperformed in terms of total and annual returns but achieved smaller volatility and a smaller maxmimum drawdown, suggesting that the portfolio was more stable than the S&P500. Furthermore, with a higher Sortino ratio, it suggests that the portfolio did not outperform the S&P500 index in absolute terms but showed a better risk profile. The portfolio provides a slightly lower return for a slightly smaller risk, which might be preferable for an investor with a smaller risk appetite.

# %% [markdown]
# ### 3. How would you evaluate whether this is a profitable strategy, and what tests would you conduct to assess its robustness?

# %% [markdown]
# Despite a high total return of 3189.11% over the long backtesting period and a positive expectancy of 2.64, its  annual return (8.46%) is not high given that this value is not inflation adjusted and the benchmark for S&P500 is an inflation-adjusted annual return of about 7%. This suggests that the high returns had occurred over a long period (given that the start of the backtesting date range was 1989-01-01). The non-optimised Sharpe ratio of the portfolio was 0.43, suggests that the ecess return per unit of volatility of the trading strategy is relatively low with the benchmark for Sharpe ratios for good strategies to be above 1.0. Furthermore, the Sortino ratio of 0.58, which is less than 1.0, that focuses on downside risk also highlights that there is high downside volatility. Lastly, with a win rate of 37.95%, it suggests that the strategy loses more often than it wins, suggesting that the strategy is not a profitable strategy in the short run but it might yield small profits in the long run.
#
# To assess its robustness, I would conduct walk-forward analysis where I split the backtesting period into smaller intervals of 5-year periods and backtest the trading strategy over each interval. This is especially because different market conditions affect the robustness of trading strategies. For example, in the context of using RSI as a trading strategy, under economic conditions that might cause a market to have high volatility, the fluctuation of prices might cause the RSI to reach extreme levels more often, giving more frequent buy and sell signals which might increase the likelihood of false signals. Hence, period-specific market conditions might influence the effectiveness of a trading strategy and splitting hisotircal data into different periods will allow for better optimisation of parameters.
#
# In the same vein, splitting historical data into pre-specified time periods can also allow for stress testing where we examine how the strategy would perform during extreme market conditions like the 2008 Financial Crisis or the COVID-19 pandemic in 2020. A robust strategy should be able to perform well not just in bullish markets, but also be able to handle downturns.
#
# Lastly, sensitivity analysis can also be conducted to identify whether the trading strategy performs well across a few parameters, for example, adjusting the RSI threshold to 70/30 or adjusting the window period. If performance varies greatly with small changes to the parameters, the strategy may be sensitive and more prone to failure under different conditions, making the trading strategy less reliable.

# %% [markdown]
# ### 4. Do you have any suggestions to improve the current strategy?

# %% [markdown]
# We can combine RSI with trend indicators such as moving averages to prevent RSI from giving false signals in trending markets. For example, we can take RSI buy signals only if the stock is above its 100-day moving average, indicating a long-term upward trend or we can take the RSI sell signal only if the stock is below its 100-day moving average, indicating a long-term downward trend. Trend indicators can help to prevent us from entering trades that go against the market trend.
#
# We could also implement dynamic RSI thresholds based on volatility, where we adjust RSI thresholds based on the existing market volatility. For example, during high volatility periods or for stocks that have higher volatility, we can use more stringent RSI thresholds and conversely during low volatility periods or for stocks that have lower volatility, we can use less stringent RSI thresholds. This helps to handle larger price swings, reducing false signals in volatile periods or in volatile stocks.
#
# Lastly, instead of only relying solely on the RSI to exit trades, we can implement a stop-loss and take-profit mechanism. For example, we can set a stop-loss that is based on a percentage of a stock's average true range to take into account the stock's usual price movement, triggering the stop loss only when the stock fluctuates downwards significantly from the average true range. Similarly, we can set a take-profit level that is based on a percentage of a stock's average true range, to provide room for more volatile stocks to move without triggering an exit prematurely.
